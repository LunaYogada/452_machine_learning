# %% [markdown]
# # Part 3: Text Data

# %% [markdown]
# # Summary of the business problem

# %% [markdown]
# This task to do sentiment analysis on IMDB movie comments to understand the audience reference of movies.

# %% [markdown]
# # Solution details

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in e:\application\anaconda\lib\site-packages
# Requirement already satisfied: six in e:\application\anaconda\lib\site-packages (from nltk)
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ## load package

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import WordPunctTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re, string
from nltk.collocations import *
import os
from nltk.stem import PorterStemmer
import sys
import re
from sklearn.feature_extraction import FeatureHasher
import numpy as np

# %% [markdown]
# ## load data

# %%
train_path = "aclImdb/train/" # source data
test_path = "aclImdb/test/" # test data for grade evaluation.

# %% [markdown]
# ## Remove stopwords

# %% [markdown]
# REMOVE_STOPWORDS takes a sentence and the stopwords as inputs and returns the sentence without any stopwords
# Sentence - The input from which the stopwords have to be removed
# Stopwords - A list of stopwords

# %%
def remove_stopwords(sentence, stopwords):
    sentencewords = sentence.split()
    resultwords  = [word for word in sentencewords if word.lower() not in stopwords]
    result = ' '.join(resultwords)
    return result

# %% [markdown]
# IMDB_DATA_PREPROCESS explores the neg and pos folders from aclImdb/train and creates a output_file in the required format
# Inpath - Path of the training samples
# Outpath - Path were the file has to be saved
# Name  - Name with which the file has to be saved
# Mix - Used for shuffling the data

# %%
def imdb_data_preprocess(inpath, outpath="./", name="imdb_tr.csv", mix=False):
    sw= stopwords.words("english")
    indices = []
    text = []
    rating = []

    i =  0 

    for filename in os.listdir(inpath+"pos"):
        data = open(inpath+"pos/"+filename, 'r' , encoding="ISO-8859-1").read()
        data = remove_stopwords(data, sw)
        indices.append(i)
        text.append(data)
        rating.append("1")
        i = i + 1

    for filename in os.listdir(inpath+"neg"):
        data = open(inpath+"neg/"+filename, 'r' , encoding="ISO-8859-1").read()
        data = remove_stopwords(data, sw)
        indices.append(i)
        text.append(data)
        rating.append("0")
        i = i + 1
    
    Dataset = list(zip(indices,text,rating))

    if mix:
        np.random.shuffle(Dataset)

    df = pd.DataFrame(data = Dataset, columns=['row_Number', 'text', 'polarity'])
    df.to_csv(outpath+name, index=False, header=True)

    pass

# %%
imdb_data_preprocess(train_path)

# %%
data = pd.read_csv("imdb_tr.csv",header=0, encoding = 'ISO-8859-1')
data.head()
# Out:
#    row_Number                                               text  polarity
# 0           0  Bromwell High cartoon comedy. ran time program...         1
# 1           1  Homelessness (or Houselessness George Carlin s...         1
# 2           2  Brilliant over-acting Lesley Ann Warren. Best ...         1
# 3           3  easily underrated film inn Brooks cannon. Sure...         1
# 4           4  typical Mel Brooks film. much less slapstick m...         1

# %%
def retrieve_data(name="imdb_tr.csv", train=True):
    import pandas as pd 
    data = pd.read_csv(name,header=0, encoding = 'ISO-8859-1')
    X = data['text']
    
    if train:
        Y = data['polarity']
        return X, Y

    return X

# %% [markdown]
# ## Tokenize

# %%
sent = []
for i in range(0,len(data["text"])):
               par = data["text"][i]
               sent.append(sent_tokenize(par))    
sent
# Out:
# [['Bromwell High cartoon comedy.',
#   'ran time programs school life, "Teachers".',
#   '35 years teaching profession lead believe Bromwell High\'s satire much closer reality "Teachers".',
#   "scramble survive financially, insightful students see right pathetic teachers' pomp, pettiness whole situation, remind schools knew students.",
#   'saw episode student repeatedly tried burn school, immediately recalled ......... .......... High.',
#   "classic line: INSPECTOR: I'm sack one teachers.",
#   'STUDENT: Welcome Bromwell High.',
#   'expect many adults age think Bromwell High far fetched.',
#   "pity isn't!"],
#  ['Homelessness (or Houselessness George Carlin stated) issue years never plan help street considered human everything going school, work, vote matter.',
#   "people think homeless lost cause worrying things racism, war Iraq, pressuring kids succeed, technology, elections, inflation, worrying they'll next end streets.<br /><br />But given bet live streets month without luxuries home, entertainment sets, bathroom, pictures wall, computer, everything treasure see like homeless?",
#   "Goddard Bolt's lesson.<br /><br />Mel Brooks (who directs) stars Bolt plays rich man everything world deciding make bet sissy rival (Jeffery Tambor) see live streets thirty days without luxuries; Bolt succeeds, wants future project making buildings.",
#   "bet's Bolt thrown street bracelet leg monitor every move can't step sidewalk.",
#   "He's given nickname Pepto vagrant written forehead Bolt meets characters including woman name Molly (Lesley Ann Warren) ex-dancer got divorce losing home, pals Sailor (Howard Morris) Fumes (Teddy Wilson) already used streets.",
#   "They're survivors.",
#   "Bolt isn't.",
#   'He\'s used reaching mutual agreements like rich fight flight, kill killed.<br /><br />While love connection Molly Bolt necessary plot, found "Life Stinks" one Mel Brooks\' observant films prior comedy, shows tender side compared slapstick work Blazing Saddles, Young Frankenstein, Spaceballs matter, show like something valuable losing next day hand making stupid bet like rich people know money.',
#   'Maybe give homeless instead using like Monopoly money.<br /><br />Or maybe film inspire help others.'],
#  ['Brilliant over-acting Lesley Ann Warren.',
#   'Best dramatic hobo lady ever seen, love scenes clothes warehouse second none.',
#   'corn face classic, good anything Blazing Saddles.',
#   'take lawyers also superb.',
#   'accused turncoat, selling boss, dishonest lawyer Pepto Bolt shrugs indifferently "I\'m lawyer" says.',
#   'Three funny words.',
#   'Jeffrey Tambor, favorite later Larry Sanders show, fantastic mad millionaire wants crush ghetto.',
#   'character malevolent usual.',
#   'hospital scene, scene homeless invade demolition site, all-time classics.',
#   'Look legs scene two big diggers fighting (one bleeds).',
#   'movie gets better time see (which quite often).'],
#  ['easily underrated film inn Brooks cannon.',
#   'Sure, flawed.',
#   'give realistic view homelessness (unlike, say, Citizen Kane gave realistic view lounge singers, Titanic gave realistic view Italians IDIOTS).',
#   'Many jokes fall flat.',
#   'still, film lovable way many comedies not, pull story traditionally reviled members society truly impressive.',
#   'Fisher King, crap, either.',
#   'complaint Brooks cast someone else lead (I love Mel Director Writer, much lead).'],
#  ['typical Mel Brooks film.',
#   'much less slapstick movies actually plot followable.',
#   'Leslie Ann Warren made movie, fantastic, under-rated actress.',
#   'moments could fleshed bit more, scenes could probably cut make room so, all, worth price rent see it.',
#   'acting good overall, Brooks good job without characteristic speaking directly audience.',
#   'Again, Warren best actor movie, "Fume" "Sailor" played parts well.'],
#  ['comedic Robin Williams, quirky/insane Robin Williams recent thriller fame.',
#   "hybrid classic drama without over-dramatization, mixed Robin's new love thriller.",
#   'thriller, per se.',
#   "mystery/suspense vehicle Williams attempts locate sick boy keeper.<br /><br />Also starring Sandra Oh Rory Culkin, Suspense Drama plays pretty much like news report, William's character gets close achieving goal.<br /><br />I must say highly entertained, though movie fails teach, guide, inspect, amuse.",
#   'felt like watching guy (Williams), actually performing actions, third person perspective.',
#   'words, felt real, able subscribe premise story.<br /><br />All all, worth watch, though definitely Friday/Saturday night fare.<br /><br />It rates 7.7/10 from...<br /><br />the Fiend :.'],
#  ['Yes art... successfully make slow paced thriller.<br /><br />The story unfolds nice volumes even notice happening.<br /><br />Fine performance Robin Williams.',
#   'sexuality angles film seem unnecessary probably affect much enjoy film.',
#   'However, core plot engaging.',
#   'movie rush onto still grips enough keep wondering.',
#   'direction good.',
#   'Use lights achieve desired affects suspense unexpectedness good.<br /><br />Very nice 1 time watch looking lay back hear thrilling short story!'],
#  ['"critically acclaimed psychological thriller based true events, Gabriel (Robin Williams), celebrated writer late-night talk show host, becomes captivated harrowing story young listener adoptive mother (Toni Collette).',
#   'troubling questions arise boy\'s (story), however, Gabriel finds drawn widening mystery hides deadly secret? "',
#   'according film\'s official synopsis.<br /><br />You really STOP reading comments, watch film NOW...<br /><br />The "How lose leg?"',
#   'ending, Ms. Collette planning new life, chopped off, sent "deleted scenes" land.',
#   'overkill.',
#   'true nature physical mental ailments obvious, time Mr. Williams returns New York.',
#   'Possibly, blindness could question - revelation could made certain either "highway" "video tape" scenes.',
#   'film would benefit re-editing - "director\'s cut"?',
#   '<br /><br />Williams Bobby Cannavale (as Jess) seem, initially, believable couple.',
#   'scene two establishing relationship might helped set stage.',
#   'Otherwise, cast exemplary.',
#   'Williams offers exceptionally strong characterization, "gay impersonation".',
#   'Sandra Oh (as Anna), Joe Morton (as Ashe), Rory Culkin (Pete Logand) perfect.<br /><br />Best all, Collette\'s "Donna" belongs creepy hall fame.',
#   'Ms. Oh correct saying Collette might be, "you know, like guy \'Psycho\'."',
#   'several years organizations giving acting awards seemed reach women, due slighter dispersion roles; certainly, could noticed Collette award consideration.',
#   'good.',
#   'And, director Patrick Stettner definitely evokes Hitchcock - even makes getting sandwich vending machine suspenseful.<br /><br />Finally, writers Stettner, Armistead Maupin, Terry Anderson deserve gratitude flight attendants everywhere.<br /><br />******* Night Listener (1/21/06) Patrick Stettner ~ Robin Williams, Toni Collette, Sandra Oh, Rory Culkin'],
#  ['NIGHT LISTENER (2006) **1/2 Robin Williams, Toni Collette, Bobby Cannavale, Rory Culkin, Joe Morton, Sandra Oh, John Cullum, Lisa Emery, Becky Ann Baker.',
#   '(Dir: Patrick Stettner) <br /><br />Hitchcockian suspenser gives Williams stand-out low-key performance.<br /><br />What celebrities fans?',
#   'near paranoia one associates almost norm?',
#   "<br /><br />In latest derange fan scenario, based true events less, Williams stars talk-radio personality named Gabriel one, reads stories he's penned airwaves accumulated interesting fan form young boy named Pete Logand (Culkin) submitted manuscript travails troubled youth one's editor Ashe (Morton) gives one read himself.",
#   '<br /><br />No one naturally disturbed ultimately intrigued nightmarish existence Pete abducted sexually abused years finally rescued nurse named Donna (Collette giving excellent performance) adopted boy correspondence one reveals Pete dying AIDS.',
#   "Naturally one wants meet fans suddenly doubt possibly devious ulterior motives seed planted estranged lover Jess (Cannavale) whose sudden departure New York City apartment one emotional tailspin grown tempest teacup decides investigating Donna Pete's backgrounds discovering truths anticipate.<br /><br />Written Armistead Maupin (who co-wrote screenplay former lover Terry Anderson film's novice director Stettner) based true story fan's hoax found Hitchcockian moments run full tilt like good old fashioned pot-boiler does.",
#   'helps Williams gives stand-out, low-key performance conflicted good-hearted personality genuinely wants believe number one fan fact real love (the one thing escaped reality) unsettling dreadful moments creepy Collette whose one physical trait leave unmentioned underlines desperation character rattle core.<br /><br />However film runs gas eventually becomes bit repetitive predictable despite finely directed piece hoodwink mystery Stettner, pays listen inner voice: careful hope for.'],
#  ['know, Robin Williams, God bless him, constantly shooting foot lately dumb comedies done decade (with perhaps exception "Death Smoochy", bombed came cult classic).',
#   'dramas made lately fantastic, especially "Insomnia" "One Hour Photo".',
#   '"The Night Listener", despite mediocre reviews quick DVD release, among best work, period.<br /><br />This chilling story, even though include serial killer anyone physically dangerous matter.',
#   'concept film based actual case fraud still yet officially confirmed.',
#   'high school, read autobiography child named Anthony Godby Johnson, suffered horrific abuse eventually contracted AIDS result.',
#   'moved story read reports online Johnson may actually exist.',
#   'saw movie, confused feelings Robin Williams brilliantly portrayed resurfaced mind.<br /><br />Toni Collette probably gives best dramatic performance ultimately sociopathic "caretaker".',
#   'role far cry movies like "Little Miss Sunshine".',
#   'even times looked camera thought staring right me.',
#   'takes good actress play sort role, understated (yet well reviewed) role makes Toni Collette probably one best actresses generation even nominated Academy Award (as 2008).',
#   'incredible least one woman world like this, scary too.<br /><br />This good, dark film highly recommend.',
#   'prepared unsettled, though, movie leaves strange feeling end.'],
#  ['first read Armistead Maupins story taken human drama displayed Gabriel one cares loves.',
#   'said, given film version excellent story expected see past gloss Hollywood...<br /><br />Writer Armistead Maupin director Patrick Stettner truly succeeded!',
#   '<br /><br />With right amount restraint Robin Williams captures fragile essence Gabriel lets us see struggle issues trust personnel life(Jess) world around him(Donna).<br /><br />As introduced players drama reminded nothing ever seems smallest event change lives irrevocably.',
#   "request review book written young man turns life changing event helps Gabriel find strength within carry move forward.<br /><br />It's bad people avoid film.",
#   'say average American probably think "Robin Williams serious role?',
#   'work before!"',
#   'PLEASE GIVE MOVIE CHANCE!',
#   'Robin Williams touches darkness must find go better people.',
#   'Like movie One Hour Photo stepped actor made another quality piece art.<br /><br />Oh forget, believe Bobby Cannavale Jess steals every scene in.',
#   "1940's leading man looks screen presence.",
#   'hacks opinion could carry movie right now!',
#   '!<br /><br />S~'],
#  ['liked film.',
#   'action scenes interesting, tense well done.',
#   'especially liked opening scene semi truck it.',
#   'tense action scene seemed well done.<br /><br />Some transitional scenes filmed interesting ways time lapse photography, unusual colors, interesting angles.',
#   'Also film funny several parts.',
#   'also liked evil guy portrayed too.',
#   "I'd give film 8 10."],
#  ['many illnesses born mind man given life modern times.',
#   'Constant vigilance accrued information realm Pyschosis, kept psychologists, counselors psychiatrists busy enough work last decades.',
#   'Occasionally, mental phenomenon discover knowledge remedy even existence.',
#   'premise film entitled " Night Listner."',
#   'tells story popular radio host called Gabriel Noon (Robin Williams) spends evenings enthralling audiences vivid stories Gay lifestyles.',
#   'Perhaps show losing authentic veneer causes Noon admit longer himself.',
#   'Feeling abandoned lover Jess (Bobby Cannavale) best friend (Joe Morton), seeks shelter deepening despair isolation.',
#   'here, mysterious voice night asks help.',
#   'Noon needs feel useful reaches desperate voice belongs 14 year old boy called Peter (Rory Culkin).',
#   "reading boy's harrowing manuscript depicts early life sexual abuse hands brutal parents, Noon captivated wants help.",
#   'However, things seem Noon soon finds en-wrapped elusive bizarre tale torn right medical nightmare.',
#   'movie pure Robin Williams Toni Collette plays Donna D. Logand, Sandra Oh Anna John Cullum pop, might comical.',
#   "Instead, may prove one William's serious performances.",
#   '***'],
#  ['enjoyed Night Listener much.',
#   'one better movies summer.<br /><br />Robin Williams gives one best performances.',
#   'fact, entire cast good.',
#   'played right notes characters - much little.',
#   'Sandra Oh adds wonderful comic touch.',
#   'Toni Collette great Mom, never goes top.',
#   "Everyone believable.<br /><br />It's short movie, hour half.",
#   'noticed general release version nine minutes shorter Sundance version.',
#   'wonder disturbing images cut movie.<br /><br />The director told story straightforward fashion, refreshing change many directors days seem think job impress audience rather tell story tell well.<br /><br />Do sucker punched previews ads.',
#   'Hitchcockian thriller.',
#   'See Night Listener want see good story told well.',
#   'go expecting Hitchcock disappointed.<br /><br />My complaint movie ending.',
#   "director could left little audience's imagination, minor quibble."],
#  ["Night Listener probably one William's best roles, makes interesting character somewhat odd different movie.",
#   'guarantee never seen kind movie before.',
#   'people maybe like slow pacing movie, think great plus movie.',
#   'definitely one top movies come year 2006. intriguing performance movie great content, dramatic feeling.',
#   'americanized movie.',
#   'Neither predictable movie.',
#   'feel movie secrets hard time determine outcome may be.',
#   'excellent movie everything, hell, damn good original movie.'],
#  ['Like one previous commenters said, foundations great movie something happened way delivery.',
#   "waste Collette's performance eerie Williams believable.",
#   'kept waiting get better.',
#   'think bad editing needed another director, could film.',
#   'came across Canadian movie, something like first seasons X-Files.',
#   'cheap, hokey.',
#   'Also, needed little suspense.',
#   'Something makes jump seat.',
#   'movie reached moment faded away; kind like false climax.',
#   'see suspenseful would taken away "reality" story thought part reached Gabriel hospital looking boy.',
#   "movie needs Director's cut tries fix problems."],
#  ['Night Listener held attention, Robin Williams shining New York City radio host becomes enamored friendship 14 year old boy (Rory Culkin) ill. Williams never met boy person, contact talking telephone.',
#   "However, Williams' ex-boyfriend (nice job Bobby Cannavale) raises doubt boy, prompts Williams arrange meeting person.",
#   'follows makes permanent impact Williams way expect.',
#   'leave that.',
#   "Toni Collette also stars.<br /><br />I enjoyed film, Toni Collette giving memorable portrayal Culkin's adoptive mother.",
#   "Sandra Oh also starred Williams' friend.",
#   'Night Listener inspired actual events, somber, almost creepy silence throughout.',
#   'times predictable, thanks reviews read seeing movie due logic, liked anyway.',
#   'enjoy Williams roles like this, comedic characters added bonus me.',
#   'Recommended.',
#   '8/10'],
#  ['Popular radio storyteller Gabriel one(Robin Williams,scraggy speaking hushed,hypnotic tones) becomes acquainted friends fourteen-year-old boy Wisconsin named Pete Logand(Rory Culkin),who written book detailing sexual abuse parents.',
#   'boot,Pete AIDS compels Gabriel still,since partner Jess(Bobby Cannavale,good)happens survivor HIV himself.',
#   "<br /><br />He also acquaints Pete's guardian,a woman named Donna(Toni Collette,brilliant!",
#   ')and Gabriel decides wants meet talk two person goes Wisconsin,he discovers secrets was(naturally)not prepared find.<br /><br />Based real events happened Armistead Maupin(who co-wrote screenplay Terry Anderson)and directed Patrick Stetner,this film moves lot faster(90 min.,maybe minutes longer)than one might think movie genre would run.',
#   "That's good keeps action storyline lean clear.",
#   'bad leaves various holes plot sew-up plot openings back-story.',
#   "I'd rather go great detail except say that,if familiar Mr.Maupin's works personal story,you feel little bit loop here.",
#   "Still,the performances Williams( would've loved heard narration,personally),Collette,Cannavale,Culkin much supporting cast(the Waitress restaurant Collete's Donna frequents great job small part has!",
#   ')are top-notch mood established here--namely,the chilly,lonely dark exteriors Wisconsin New York--give terrific framing story.',
#   'may ends tie together particularly well,but still compelling enough story stick with.'],
#  ['one thing recommend film intriguing.',
#   'premise certainly draws audience mystery, throughout film hints something dark lurking about.',
#   "However, much tension, Williams' mild mannered portrayal much makes us relate obsession boy.<br /><br />Collete fares much better woman whose true nature intentions clear.",
#   'production felt rushed holes apparent.',
#   'certainly feels like preview much complete better effort.',
#   'book probably better.<br /><br />One thing certain: Taupin must written something truly good inspired least one commendable effort.'],
#  ['absolutely LOVED film!',
#   'relate comments read it.',
#   'COMPLETELY enthralled every second!',
#   '<br /><br />I found story gripping, acting intense, direction spot-on.',
#   'would literally jump every time phone would ring close end movie.',
#   'Even though nothing "scary" story itself, soundly edge whole movie - rest evening.',
#   '<br /><br />I found many perfect choices made...the casting, script, little bits humor sprinkled it.',
#   "many points film could've gone cheap thrill, never did, put movie many mediocre thrillers come lately...and last number years."],
#  ['Night Listener better people generally saying.',
#   'weaknesses, seems genre identity crisis, doubt, think creepy atmosphere intriguing performances make this.',
#   'whole thing feels like one fireside "this happened friend friend mine" ghost stories.',
#   'One big complaint movie pacing: slow sometimes awkward pacing deliberate.',
#   'Everything unfolds movie kept well within realm possibility, real life sort plods along??no?',
#   'flashy endings earth-shattering revelations, "showdown" scenes.',
#   'Thank Heaven.',
#   'get zone watching movie, forget reservations expectations makes (conventionally)good movie.',
#   'Williams terrific, easily meets needs story, plus character supposed somewhat generic ("No One") Everyman, avatar enter story.',
#   "Toni Collette's performance nominated Oscar (even maybe win it).",
#   'Give shot.',
#   'quality content alone, Night Listener surely top twenty percent movies coming days.'],
#  ["comes movies pretty picky, I'll complain anything everything done wrong.",
#   'every movie flaws, Night Listener exceptionally low count.<br /><br />If read last review (it hard, since half written caps contained actual information movie), may led believe movie well done.',
#   "Unfortunately, read 3 lines review, discovered poster's reason disdain: he/she like fact director gay (or production team smokes crack...apparently).<br /><br />So, despite fact never written review before, thought movie deserved one based merits, sexual orientation director.",
#   "Let's go quick checklist first: 1.",
#   'Great plot?',
#   'Absolutely.',
#   'give shred away, plot highly compelling definitely one would expect based commercials.',
#   'thriller, horror, approached such.',
#   'story really amaze you, even true (and plot stay quite faithful actual events).<br /><br />2.',
#   'Wonderful Acting?',
#   'Oh Yes.',
#   'Robin Williams long ago broke free chains comedy type-cast, since flourished serious roles many people would wrote decade ago.',
#   "achieves high form role Night Listener, playing radio host becomes increasingly troubled entangled case of...well, I'll let see yourself.<br /><br />3.",
#   'Excellent direction?',
#   'Certainly.',
#   'Now, unlike poster referred, actually know something direction.',
#   "I've sutdying art direction school 3 years.",
#   'course really think makes lick difference (the thing matters like direction), thought simply establish I\'m basing opinions something substantial relevant...for example: sexual orientation director (or alleged drug habits production team, LOL).<br /><br />Patrick Stettner\'s direction moody dark, allowed angles lighting help create so-sought-after feelings "tension release" rather messy, fast-paced camera-work quick cuts we\'re often subjected today.',
#   "people truly show story camera, other's feel make story camera.",
#   'really appreciate someone days courage use camera supposed utilized, eyeball see.<br /><br />4.',
#   'Lighting, cinematography, editing?',
#   'Great around.',
#   "I've already wrote much, could go last three things another ten paragraphs, I'll wrap up.<br /><br />In short, go see movie.",
#   "listen people alterior motives trashing it, especially they're stupid unknowingly reveal motive 1/4 way post.",
#   'Enjoy show!',
#   '-Ben'],
#  ['Somewhat funny well-paced action thriller Jamie Foxx hapless, fast-talking hoodlum chosen overly demanding U.S. Treasury Agent (David Morse) released streets New York find picky computer thief/hacker (Doug Hutchinson), stole forty-two million dollars treasury left two guards shot dead.<br /><br />"Bait" marks sophomore feature Antoine Fuqua ("The Replacement Killers") handles task fairly well even though top first movie.',
#   'two films common action sequences, flat-out excellent.<br /><br />Foxx pretty good although character annoying beginning, throughout film, began catch on.',
#   'Hutchinson marvelous mastermind ruthless John Malkovich patient late Laurence Olivier "Marathon Man".',
#   'Morse okay agent comes ingenious plan get whoever cost.'],
#  ['legendary Boris Karloff ended illustrious career making four cheapie fright flick clunkers Mexico.',
#   'token moody period Gothic horror entry bunch.',
#   'Karloff gives typically spry dignified performance Matthias Morteval, elderly eccentric patriarch invites several petty, greedy backbiting no-count relatives creepy rundown castle reading will.',
#   'Pretty soon hateful guests getting bumped lethal life-sized toy people populate place.',
#   'Onetime Mexican sex symbol Andres Garcia "Tintorera" infamy portrays dashing police officer hero Julissa looks absolutely ravishing sole likable female character.',
#   'clunky, plodding (non)direction, trite by-the-numbers script, ugly, washed-out cinematography, ridiculous murder set pieces (a gross fat slob gets blasted right face miniature cannon!',
#   '), overwrought string score, morbid gloom-doom atmosphere, largely lousy acting (Karloff notably excepted), cheesy mild gore, poor dubbing rousing fiery conclusion lend enjoyably awful lemon certain endearingly cruddy hence oddly amusing ratty charm.',
#   'real campy hoot.'],
#  ['tale based two Edgar Allen Poe pieces ("The Fall House Usher", "Dance Death" (poem) ) actually quite creepy beginning end.',
#   'similar old black-and-white movies people meet old decrepit house (for example, "The Cat Canary", "The Old Dark House", "Night Terror" on).',
#   'Boris Karloff plays demented inventor life-size dolls terrorize guests.',
#   'dies early film (or ? )',
#   'residents house subjected number terrifying experiences.',
#   'go much detail here, definitely must-see fans old dark house mysteries.<br /><br />Watch plenty popcorn soda darkened room.<br /><br />Dan Basinger 8/10'],
#  ["Aro Tolbukhin burnt alive seven people Mission Guatemala 70's.",
#   'Also declared murdered another 16 people (he used kill pregnant women, set fire).<br /><br />This movie documentary portraits personality Aro several interviews people got know scenes played actors based real facts.<br /><br />"Aro Tolbukhin" serious work, analytical, morbid all.',
#   'horrifying testimony childhood trauma turn man monster.<br /><br />*My rate: 7/10'],
#  ['seeing several movies Villaronga, pretty clear opinion -- concentrates much personal aspect characters, forgetting rhythm movie.',
#   'why, though good critics, movies never caught broad audience attention.',
#   'ARo follows line, really improved rhythm, especially end movie.',
#   'Frankly speaking, slept first part, cause though first part gives necessary information, really slow.',
#   'Nevertheless second part absolutely marvelous makes whole movie best movie ever made Villaronga.<br /><br />Recommended.'],
#  ["There's many things fall Aro Tolbukhin.",
#   "En la mente del asesino (Inside killer's mind), hard talk without giving kind warning.",
#   "Let's say movie like exercise cinema really, really great done.",
#   'It?',
#   '?s made super 8, black white shots, 35 milimeters, color, interviews, flashbacks.',
#   'Aro Tolbukhin it?',
#   '?s like movie made documental viceversa, peculiar aspect relays doubt leaves wondering, really ever existed?',
#   'movie follows later life hungarian sailor arrived Guatemala, worked religious mission killed people.',
#   'act got caught death penalty sentenced.',
#   'movie starts french documentalists got interested character interview prior death.',
#   'Nowadays, people got involved make deeper research character.',
#   'one witness -the movie.<br /><br />For main part history guided semi slow phase go look inside Aro?',
#   '?s mind, mainly order decode done.',
#   'Nevertheless, important thing filmmakers never gives us sided point view; left judging us even may understand actions, clearly never justify them.',
#   "So, first half based upon recollecting information; later things turn Aro's childhood, giving movie incredible new force (even tough never got weak boring).<br /><br />I mean -and want- spoil anything; thing left say chance get movie near you, believe me, trip see worthy."],
#  ['got unique twists two genres ever seen.',
#   'giant monster movie genre living mummy movie genre.',
#   'unique blend makes unique compelling story.',
#   'casts outstanding, including TOM BOSLEY far know never horror movie before, ever.',
#   'effects impressive idea giant mummy filled smaller mummies cool one.',
#   'one complaint, wish saw giant mummy, think great job.',
#   'dialog, characters story perfect.',
#   'acting wonderful.',
#   'got best movie come sci-fi channel.',
#   'heard me, best movie come sci-fi channel.',
#   'give FALLEN ONES 9 10.'],
#  ['Without Kirsten Miller project completed.',
#   'However awe inspiring beauty talent Miss Miller would definitely recommend it.',
#   'looked actors playing strong performance.',
#   "Wagner's dismal attempt honor film bit disappointing, scenes detract entertained.",
#   'Mostly criticisms writing plot line, group talent assembled heroic job salvaging disaster.',
#   'charismatic Miller delivery timing impeccable believable.',
#   'plays fine line assertive bossy never offensive fact structural engineer claims be.',
#   'wish seen big screen alas fortunate rent lost.'],
#  ['Sure, Titanic good movie, first time see it, really see second time opinion film definetly change.',
#   'first time see movie see underlying love-story think: ooh, romantic.',
#   'second time (and one think this) annoying sit watching movie thinking, d**n ship going sink???',
#   'even impressive see several times.',
#   'acting film bad, definetly great either.',
#   'glad DiCaprio win oscar film, mean think is, Anthony Hopkins Denzel Washington?',
#   '1 half-good movie film less $20 million.',
#   'everyone suprised hardly films it.',
#   'enough about, eyes, worst character film.',
#   "Kate Winslet's performance hand wonderful.",
#   'also tink director talented put film magnitude together.',
#   'one lesson learned movie: many love-stories is, filmmakers try add crummy romance every single movie!!!',
#   'possible 100% give film mere 71%.'],
#  ['saw movie stunned great movie was.',
#   'movie think would ever give 10 star rating.',
#   'sure movie always top 5.<br /><br />The acting superb.',
#   'Leonardo DiCaprio Kate Winslett best.',
#   'think anyone could better job Kate.',
#   "<br /><br />If rainy day can't decide rent, well, one.",
#   'love acting, special effects, much much more.<br /><br />If seen movie go rent buy now!!!',
#   'regret it.<br /><br />'],
#  ['people bitch movie awful movies like Godfather.',
#   'Titanic greatest movie 21st Century.With great acting,directing,effects,music generally everything.',
#   'movie always dumped one day one said like world decided agree.',
#   'nothing wrong movie.',
#   "say movie, heavily Oscar Awarded movie time, money ever made ever sadly one underrated movies I've ever seen.",
#   'Apart truly best movie time.',
#   'movies come close like Star Wars Lord Rings trilogy anything masters Hitchcock Spielberg Tim Burton.',
#   "good movies directors none match James Cameron's Masterpiece TITANIC."],
#  ['two comments....SEVEN years apart?',
#   "Hardly evidence film's relentless pulling-power!",
#   'mentioned, low-budget telemovie status 13 GANTRY ROW mitigating factor limited appeal.',
#   'said however thing without merit - either entertainment fright outing per se.<br /><br />True, plot basic re-working AMITYVILLE HORROR - without much horror.',
#   'case intrigue!',
#   'Gibney might made worthwhile impression played Halifax -investigating couple seemingly unconnected murders "house" main suspect.',
#   'script better average production overall high standard.',
#   'fails engage viewer particularly key moments.<br /><br />Having picked DVD mere $3.95 last week regular video store, cannot begrudge expenditure.',
#   '$10.95 would acceptable price film.',
#   'expect fireworks!'],
#  ["What's inexplicable?",
#   'Firstly, hatred towards movie.',
#   'may greatest movie time, gimme break, got 11 oscars reason, made EIGHTEEN HUNDRED MILLION DOLLARS reason.',
#   'damn good movie.',
#   'brings inexplicable aspect it.',
#   'idea whatsoever movie left impression saw theaters.',
#   "I've rewatched TV video, none impact saw big screen (twice, maybe three times, actually).",
#   'might it, appeal it.',
#   'Movie, yes, capital there, Epic, spectacle order Gone Wind Ben Hur.',
#   'Now, Ben Hur Gone Wind seem kinda hokey me, hammy acting excessive melodrama.',
#   'Titanic none that.',
#   'Well, acting actually good.',
#   'melodrama quite heavy-handed times.<br /><br />But reason Titanic works emotional ride.',
#   'usually enjoy movies stimulate mind, give visual thrill.',
#   'movie exactly dumb, cerebral all.',
#   'visual thrills simply means end, fuel emotions audience.',
#   "cry Bambi's mom died, react tearjerkers.",
#   'tearjerker power ten million, emotional rollercoaster that, regular one, would make Buzz Aldrin scream like little girl.',
#   "I'm sure see video decided hate it, ready supply cynicism, thoroughly dislike movie.",
#   'let disbelief suspend bit, give epic melodrama benefit doubt, enjoy completely.',
#   'look top ten grossing films time.',
#   'single one bad?',
#   'single one worth score 1 10?',
#   'No, even Phantom Menace.',
#   'movie made 1.8 BILLION DOLLARS worldwide.',
#   "can't bad.",
#   'possible.',
#   '10/10.<br /><br />p.s.',
#   'anyone even consider comparing spiderman?',
#   'spiderman fun movie, total 9/11 kneejerk caused gross much did.',
#   'simply anything special.',
#   'one remember 50 years.',
#   "i'm pretty sure Titanic remembered."],
#  ['Previously, wrote loved "Titanic", cried ending (many times over), I\'m guy 60\'s.',
#   'also wondered great movie, many awards applauded many critics, given 7.0 rating imdb.com users.<br /><br />Well, looked breakdown user ratings.',
#   '29.0% votes gave 10 rating, 10.7% gave 1 rating.',
#   '10.7% irrational imdb users, effect, pulled overall rating 7.0.',
#   '<br /><br />In previous comments, blamed unusual voting pattern (a sudden surge 1 ratings, high 10 rating, dropping gradually suddenly reversing course jumping 1 rating level) one thing: hatred Leonardo DiCaprio.',
#   "Believe me, I've tuned enough chat rooms see banter young people (young men, mostly), defame left right.",
#   'absolutely hate man, part giving credit "Titanic".',
#   '(To answer one user: talking someone really like movie much, gave 5 6, etc.',
#   'Everyone has, entitled to, his/her taste.',
#   'one convince imdb rating 7.0 overall "Titanic", pulled level inordinate number ridiculous 1 ratings, fair reflection overall motion picture.',
#   ')<br /><br />Let demonstrate point comparing imdb user voting pattern "Titanic" 5 randomly chosen box office critical "bombs" (there many more, 5 prove point).',
#   '"Heaven\'s Gate" (1980) pulled theaters quickly poor box office showing, imdb voters\' ratings were: 23.2% 10 ratings 9.2% 1 ratings (overall rating 6.1).',
#   '"Big Top Pee-wee" (1988) got 4.3% 10 ratings 9.9% 1 ratings (overall rating 4.5).',
#   '"Cat People" (1982) got 6.1% 10 ratings 2.6% 1 ratings (overall rating 5.8).',
#   '"Blind Date" (1987) got 3.0% 10 ratings 2.8% 1 ratings (overall rating 5.3).',
#   '"Jumpin\' Jack Flash" (1986) got 4.4% 10 ratings 3.7% 1 ratings (overall rating 5.2).',
#   'FILMS COMMON "TITANIC"?',
#   'PERCENTAGES 1 RATINGS LOWER !!!!',
#   '"TITANIC", NONE STINKERS EVER NOMINATED SINGLE AWARD.',
#   'Again, "Titanic" got 10.7% 1 ratings!',
#   'Compare 5 movies mentioned.<br /><br />Can explanation hatred Leo factor?<br /><br />'],
#  ['loved movie since 7 saw opening day.',
#   'touching beautiful.',
#   'strongly recommend seeing all.',
#   'movie watch family far.<br /><br />My MPAA rating: PG-13 thematic elements, prolonged scenes disastor, nudity/sexuality language.'],
#  ['movie Titanic makes much "night remember."',
#   'writes tragic history event always talked never forgotten.',
#   'criticised?',
#   'idea.',
#   'Could/will ever make movie like Titanic moving touching every time watch it.',
#   'Could ever replace epic masterpiece.',
#   'almost impossible.<br /><br />The director doubt major impact film.',
#   'simple disaster film (boring watch) converted unbelievable romance.',
#   "Yes I'm Romance type either, bother you, never see romance like this.",
#   'Guaranteed!',
#   'Everything amazing effects, music, sublime acting.',
#   '<br /><br />The movie creates amazing visual wonderful feeling.',
#   'Everything looks real live.',
#   'legend "TITANIC" shown brilliantly classes, looks, accommodation.',
#   'acting real effect.',
#   'Dicaprio Winslet simply best playing roles.',
#   'one could done better.',
#   'partly reason film great.',
#   '<br /><br />I guess much talk about.',
#   'plot simple, acting brilliant, based true story, Probably half consumers watch film share tears, thanks un imaginable ending never forgotten.',
#   'Well seen film missing something Hesterical, film idolise Hollywood.',
#   'Could get better?',
#   'No.',
#   'all.',
#   'moving film time, listen people, see understand.',
#   'landmark.',
#   "(don't surprised cry too)"],
#  ['problems film, heard lot criticisms saying overlong overrated.',
#   'True, three hours long, amazed goes quickly.',
#   'think overrated all, think IMDb rating perfectly decent.',
#   'film looks sumptuous, gorgeous costumes excellent effects, direction James Cameron rarely slips focus.',
#   'Leonardo DiCaprio gives one best performances Jack, Kate Winslet lovely Rose.',
#   "David Warner, great actor, steals every scene he's in.",
#   'story rich detail, hot character development, obvious love story moving needs be, though first bit movie little slow.',
#   'last hour extremely riveting, confess edge seat, Titanic sank.',
#   'also say last five minutes moving.',
#   'music score James Horner lovely, though never huge fan song Heart Go On.',
#   '1996 miniseries good, suffered undeveloped scenarios historical inaccuracies.',
#   'Overall, give Titanic 8.5/10.',
#   'Bethany Cox.'],
#  ['think James Cameron might becoming favorite director second review movies.',
#   'Anyway, everyone remembers RMS Titanic.',
#   'big, fast, "unsinkable"... April 1912. news one biggest tragedies ever.',
#   'Well James Cameron decided make movie star two fictional characters spotlight instead ship.',
#   'Well, onto main review let remind opinion zero fact fact present event film.<br /><br />So two main characters Jack (Leonardo DiCaprio) Rose (Kate Winslet).',
#   "They're annoying much watch find could become annoying ( http://tinyurl.com/ojhoyn ).",
#   'main villain guess bad luck, fate, hand God (no blasphemy intended), plain Caledon Hockley (Billy Zane).',
#   'Combine get?!',
#   'Oh yes!',
#   'get love story sinking boat.',
#   'supporting characters following: personal favorite, Mr. Andrews (Victor Garber)(idk nice), Lovejoy(David Warner), Murdoch(Ewan Stewart), Lightoller (Jonathan Phillips), Captain Smith(Bernard Hill), Molly Brown(Kathy Bates), many more.',
#   'also got present day treasure hunter, Brock Lovett (Bill Paxton).',
#   'add something story, something good.',
#   'action awesome, especially second half, drama also good.',
#   'end eyes dropping rainstorms silent tears.',
#   'story simple works.',
#   'treasure hunter seeks Heart Ocean instead finds drawing woman wearing said diamond.',
#   'calls tells tale RMS Titanic.',
#   'Two lovers separated social class ultimately, fate ship.',
#   'Everything story works flaws.',
#   'give Titanic, 86% awesome'],
#  ['Titanic long well made tragic adventure love story takes place ill-fated voyage unsinkable ship.',
#   'Writer/Director James Cameron done great job making movie fictional love story two different people combining real event Titanic sunk hitting iceberg April 15, 1912 claiming thousands lives perished icy freeing waters North Atlantic.',
#   'two leads film great roles including Leonardo DiCaprio Kate Winslet.',
#   'make good on-screen couple.',
#   'DiCpario Winslet also genuine chemistry together made romance eventually blossoms much believable.',
#   'showed real talent one came continued show recently films well.',
#   'rest supporting cast including Billy Zane, Kathy Bates, Frances Fisher, Jonathan Hyde, Bill Paxton small role equally impressive characters help bring life film.',
#   'love story, action, suspense, special effects magnificent done especially time.',
#   'horror situation characters felt real really happened making want survive life death situation.',
#   'pacing little slow times little long rest movie made flaws.',
#   'Titanic makes great date movie sure make girls cry almost every time watch it.',
#   'fact really happened definitely added movie making feel sorry lives lost Titanic sunk Atlantic hitting iceberg.',
#   'Overall Titanic tragic heartbreaking story two people fall love ill-fated ship thats brought life exceptional performances cast especially DiCaprio Winslet definitely make movie worth time watch.'],
#  ["ship may sunk movie didn't!!!",
#   "Director, James Cameron, 'The Terminator' amazing picture.",
#   "One favorite scenes 'The Dinner table' scene, Rose's family friends meet Jack saves her.",
#   "Rose look face every woman meet 'THE ONE'...I hope look room future husband.<br /><br />Jack Rose connection 'MOVIE STUFF' good movie stuff.",
#   'greedy mom elite stuck associates live husbands wealth.',
#   'Rose almost commits suicide Gilbert Grape star rescues her.',
#   'really liked hanging boat scene.',
#   'good risk.<br /><br />The movie long fantastic!!!',
#   'Good story, good flow, good actors!!!',
#   'Go see twice want, worth it!!',
#   '!'],
#  ['Titanic one all-time favorite movies.',
#   'problems (what movies don\'t) still, enjoyable.<br /><br />When stumble across someone asks like Titanic, suppose first reaction "wait minute, don\'t?"',
#   "know many people like movie, I'm saying see why.",
#   '"The love story cheesy" well, yes enjoyable moving?',
#   'right, love story Jack Rose unrealistic, everyone knows love like actually exist.',
#   'movie, everyone enjoy watching beautiful story lets us slip slightly fantasy while?',
#   'next complaint, DiCaprio Winslet terrible actors.',
#   'Well, OK, movie, agree perform full potentials.',
#   'However think unfair say terrible actors.',
#   'personally think talented actors unfortunately famous movie amazing in.',
#   "roles given simple, characters seem real enough care quite bit, agree many people well could expected.<br /><br />And finally, one going complain like movie hate romance, hate history, tragic movies, I'm sorry earth go see movie clearly things.",
#   'like people complain Dark Knight bad movie hate action movies.',
#   "Simply movie, dislike genre, good movie.<br /><br />Well deserving Oscars, particular, Best Cinematography, find best I've ever seen movie save maybe Lord Rings trilogy.<br /><br />I know writing fails, constant screaming other's names throughout movie.",
#   'flashback portion story quite weak times, overall amazing achievement making Titanic look real, sinking feel epic.<br /><br />I understand lot people dislike movie, part boils disliking fundamental idea, love story, rather thinking movie poorly constructed.<br /><br />I tell read five books Titanic, including memoirs form day happened, movie extremely historically accurate save faults.',
#   'main ones find piping threaded copper, steel, iceberg looks fairly unrealistic scene hit it.<br /><br />I give movie 10/10, like romance movies, simply outstanding cinematic achievement, leaves one feeling horrified realistic adaptation events.'],
#  ['Titanic classic.',
#   'really surprised movie solid ten, overall IMDb user rankings.',
#   'Maybe, cool give Titanic credit nowadays, first made really something.',
#   'movie came people flocked theaters.',
#   'came video sister would watch twice day month.',
#   'safe say obsessed good reason.',
#   'disaster scenes hard forgot, like frozen baby, guy committed suicide killing someone unruly crowd.',
#   'Many people died ship, convey film immediacy emotion needed hard challenge James Cameron stepped to.',
#   "let's forget amazing romance Jack Rose.",
#   "Whether relationship figment someone's imagination lovely.",
#   'barely knew other, would die other.',
#   'trusted other.',
#   'sure hell giving Romeo Juliet run money.',
#   '"I\'ll never let go, Jack."',
#   'Titanic great film core.',
#   'powerful story told brilliant acting, excellent cinematography, beautiful music, crew full hard dedicated workers.',
#   'really blows mind someone says hate movie.'],
#  ['Another Aussie masterpiece, delves world unknown supernatural, well.',
#   'resort big special effects overkill like American flicks, focuses emotional impact.',
#   'relatively simple plot Rebecca Gibney & Co. bring life.',
#   'follows story couple buy old house supposedly home old woman never went outside, whose husband disappeared mysterious circumstances century ago.',
#   'Strange things begin happen house, John Adam begins turn man disappeared, actually mass murderer.',
#   'Highly recommended.',
#   '8/10'],
#  ['personally film goes top four time.',
#   'exceptions.',
#   'James Cameron proved time time master storyteller.',
#   'films Aliens, Abyss Terminators clear brilliant confidant director far action science-fiction goes.',
#   'sees story adds strange quality film.',
#   'Titanic much different strokes brilliance.',
#   'film exceptionally moving allows room surprises, plot development interesting character developments story everyone knows.',
#   'story famed voyager sinking maiden voyage legend challenge Cameron make truthful, interesting entertaining film it.',
#   "acting wonderful Leonardo DiCaprio plays Jack Kate Winslet plays Rose became superstars overnight release film films get annoyed supporting characters given lot film purposeful elderly Rose (Gloria Stuart) tells story quickly apparent Rose's Jack's story alone, one else.",
#   'Emotionally entirely satisfying leave dry eye theater home.',
#   'music become iconic legendary.',
#   "composer James Horner's finest soundtrack ever evokes much film audience.",
#   'song long become annoying still appreciate phenomenon film is.',
#   'one problem, usual James Cameron problem, dialogue memorable bad way cheesy points aside.',
#   'James Cameron delivered masterpiece romantic epic sweeps away journey lifetime.',
#   'heart go one.'],
#  ['Back 1997, remember year: Clinton bans cloning research, unfortunate death Princess Diana, Marlins world series woman gave birth septuplets.',
#   'also big year release Titanic, one biggest films time: tale ship dreams, boy girl fall love torn apart social class height emotional commitment ship meets disaster.',
#   'think anybody could expected Titanic HUGE was, movie bigger life millions fans, 85% teenage girls, 12 years old time, course saw movie multiple times.',
#   'film made believe love Jack Rose shared real beautiful.',
#   'time felt Titanic could wrong, course grew watch film since 14, couple years ago saw film DVD 5.99 figured good price see thought movie now.',
#   'worth hype?',
#   'really best movie time?',
#   "Leonardo's real nose?",
#   "OK, know that's silly say, re-watch film.",
#   'completely honest here, Titanic great movie, best movie time, no, depends idea good movie, Titanic delivered romance, humor, disaster, emotions never let us go maiden voyage.<br /><br />The film starts Brock Lovett team exploring wreck RMS Titanic, searching necklace set valuable blue diamond called Heart Ocean.',
#   'Unsuccessful, instead discover drawing young woman reclining nude, wearing Heart Ocean, dated day Titanic sank.',
#   '101-year-old Rose Dawson Calvert learns drawing, contacts Lovett inform woman drawing.',
#   'granddaughter Elizabeth "Lizzy" Calvert visit Lovett skeptical team salvage ship.',
#   'asked knew whereabouts necklace, Rose Calvert recalls memories aboard Titanic, revealing first time Rose DeWitt Bukater.',
#   '1912, upper-class 17-year-old Rose boards ship fianc?',
#   "?, Cal Hockley mother, Ruth DeWitt Bukater, stress importance Rose's engagement Cal since marriage mean eradication Dewitt-Bukater debts: outward appearance upper-class, Rose mother financially broke.",
#   'Distraught frustrated engagement controlling Cal pressure mother putting go marriage, Rose attempts suicide jumping stern.',
#   'leaps, drifter artist named Jack Dawson intervenes.',
#   'Jack Rose strike tentative friendship thanks saving life, shares stories adventures traveling sketching; bond deepens leave stuffy first-class formal dinner rapport-building wealthy much livelier gathering Irish dance, music beer third-class.',
#   "Cal's servant informs Rose's whereabouts', Rose forbidden seeing Jack again.",
#   'However, witnessing woman encouraging seven-year-old daughter behave like "proper lady" tea, Rose defies mother, asking Jack sketch nude wearing Heart Ocean, engagement present Cal.',
#   "beautiful moment together first backseat fun time, go deck ship.<br /><br />They witness ship's fatal collision iceberg.",
#   "overhearing ship's lookouts discussing serious collision is, Rose tells Jack warn mother Cal.",
#   "Meanwhile, Cal discovers Rose's nude drawing taunting note safe, frames Jack stealing Heart Ocean Lovejoy plant Jack's pocket.",
#   'Upon learning Cal intends leave Jack die deck, Rose runs away mother rescue him.',
#   'Jack Rose return top deck.',
#   'Cal Jack, though enemies, want Rose safe, persuade board lifeboat.',
#   "realizing cannot leave Jack, Rose jumps back ship reunites Jack ship's first class staircase.",
#   'Jack Rose return top deck, lifeboats gone, ship finally goes freezing Atlantic taking Jack Rose down.<br /><br />So Titanic live hype?',
#   'still say great movie watch, think still quite haters reason want trash movie ton awards everyone love movie.',
#   'great acting, amazing effects, well-written story still looks flawless.',
# ...
#   "surprisingly average slasher, that's enjoyable,and well made, decent gore, say well worth watch!.",
#   'Direction good.',
#   'Kimble Rendall good!',
#   'job solid camera work, using creepy setting, good angles keeping film fast moving pace.',
#   'acting solid!.',
#   "Molly Ringwald plays bitch extremely well,and troubles feeling sorry her, supposed heroine, turned better towards end, much, I'm surprised decided film, nonetheless excellent job!.",
#   'Frank Roberts fantastic killer, menacing, creepy one hell mask, guy mess around, fantastic!.',
#   'Kylie Minogue plays bitch well small role.',
#   'Jessica Napier cute fine heroine.',
#   'Rest cast fine.',
#   'Overall well worth watch!.',
#   '*** 5'],
#  ['slasher flick,this movie actually better lot genre.yes predictable-resident nut job goes killing spree,people die,yada yada yada.however good positives film.first off,i really liked mask nut job wore.it definitely creepy say least possibly unique(although watched every single slasher film ever made)also,the genesis bad due something seen before,and way finally meets end novel concept,as far know.i also really liked weapon choice employed Mr sicko,for murders.the murders graphic genre,but that\'a small concern.the movie take seriously,which something slashers suffer from.oddly enough,while watching movie,i reminded early "Friday 13th films,which take seriously.there concerns movie.in several scenes,the killer suddenly bears strong resemblance one horror icons.by this,i mean movements reactions upon shot,and also way walked.of bigger concern,however scene close end,where Mr crazy bears striking resemblance(actually complete rip off)of another famous horror titan.and last scenes,we scumbag,once again,looking exactly like 1st horror icon mentioned.in fact last scene almost complete rip-off another icon slasher genre.',
#   'scenes weak unoriginal(obviously).by way,the movie set Australia,so sucker chick Aussie accent(like me)you\'ll heaven.if not,than might grate you.one great thing movie:beautiful Kylie Minogoue(just get attached her)there one non Aussie accent,courtesy Molly Ringwald.overall,there reasons watch not.i enjoyed fun.so,i give "Cut" 8/10,which may seem high people.'],
#  ['Twelve years ago, production stopped slasher flick "Hot Blooded" since almost everyone set started dying.',
#   "Now, couple film students decided finish film, despite fact there's rumor film cursed.",
#   "Well, they're find curses real.<br /><br />When Scream released, every country seemed want cash success, even Australia.",
#   'concept, today done death (a slasher film within slasher film) time relatively cool original.',
#   'movie released right Urban Legends: Final Cut Scream 3 (well US Australia) felt like first movie concept.',
#   'Urban Legends 2 released, us ready grown sick concept since movie even good, movie flopped disastrously.',
#   'Now, Cut best slasher flick ever, try be.',
#   'knows rip-off, even cast girl looks like blonde version Neve Campbell starring role.',
#   'instead trying add new original twists story, they\'ve decided rip-off 80s slasher flicks like "Nightmare Elm Street" well surprisingly enough, actually works.',
#   'killer creepy mask killer!',
#   "instead trying scare audience death, they've created good creepy atmosphere keeps us suspense movie.",
#   'couple plot holes movie though able fully ignore, ending biggest plot hole movie.',
#   'Spoiler ahead; mean, burnt copy movie hell find print show final scene?',
#   'makes sense tell you.',
#   'End spoilers.',
#   'all, Cut pretty creepy slasher flick silly story consider one better Scream rip-offs never made big.',
#   "I'm surprised one never got sequel, guess simply came late.",
#   '<br /><br />Suspenseful Australian slasher flick scares.',
#   'Cut still pretty neat slasher movie recommend one even though consider story quite silly since completely ludicrous.'],
#  ["think cheesiest guilty pleasure-type movies, first thing think '80s slasher flicks.",
#   'Really bad slasher flicks.',
#   "formulaic type film, script needed 2 parts blood several parts nudity get made.<br /><br />Flash forward late '90s/early '00s.",
#   'slasher flick revitalized success 1996\'s "Scream".',
#   'Like \'80s, films formulaic, masking lack inspiration labelling "hip, tongue-in-cheek parodies" original slasher flicks.',
#   'recent blend "hip parody" neo-slasher flicks, one worth seeing low-budget, direct-to-video "Cut".<br /><br />Like "new" slasher flicks, "Cut" relies production slasher flick, case fictional 1985 film "Hot Blooded", make commentary genre.',
#   '"Hot Blooded" never finished production, killings someone wearing mask film\'s killer, Scarman, bald figure mouth stitched close dark, pupil-less eyes.',
#   'Now, 12 years later, group film students, whose professor involved production, decided go vaults, tap original surviving actress, finish film.',
#   'every time film screened scene shot, "Scarman" returns someone dies.',
#   'quote tagline, finish film finishes them?<br /><br />This sounds really bad, degree (really, thing good slasher flick?).',
#   'character development (the "new" director revealed daughter "Hot Blooded"\'s original director, whose life apparently ruined production cancelled; would\'ve perfect detail worked plot, yet never mentioned again) and, like slasher flicks, many bodies care about.',
#   'actors great, even direct-to-video standards, fun characters (and aren\'t, inadvertent character acting, since none characters film wanted work "Hot Blooded"), particularly whoever lucky enough play Scarman.',
#   '"Cut"\'s climax big "who dunnit" unmasking killer like "Scream" films.',
#   'gimmick killings "Urban Legend" films.',
#   'original interesting concept diluted "this way write sequel sells well" ending.',
#   'that\'s par course.<br /><br />By sensible viewing standards, horrible movie avoided, "quality" makes true roots slasher genre, makes enjoyable neo-slasher flicks.'],
#  ['horror movie shot things going well.',
#   'masked killer.',
#   'director tells killer front cast crew.',
#   'goes crazy kills two people.',
#   "He's killed film never finished.",
#   "Twelve years later bunch film students decide try finish it--but there's curse.",
#   'People try finish killed themselves.',
#   'students ignore that.',
#   'Guess happens next?<br /><br />The plot old hat bad...for (a low budget slasher film).',
#   'well-made young fairly talented young cast.',
#   'one great one terrible either.',
#   'also avoids obligatory (and needless) female nude scenes.',
#   'moves quickly, gore nice bloody script insult intelligence.',
#   'Also Molly Ringwald time life playing bitchy faded actress.<br /><br />No great shakes bad all.',
#   'give 7.'],
#  ['one little Christmas movies everyone.',
#   'Scrooge Ben Affleck, decides money enough, rents family lives thought family did.',
#   'OK?',
#   "great little high school soap, PG-13, small sex references comedy, kid can't handle them, can't live real world, either.<br /><br />Now, Affleck hunk, usual walks fun, OMG, remember did..., ensemble piece end stages neuroinfectious disease.",
#   "that's OK, even old Oracle keeps hoping Ben's well proportioned over, well, there's hope us ladies yet.",
#   "Luckily, rest ensemble--Catharine O'Hara, James Gandolfini, Christina Applegate, Udo Kier Josh Zuckerman--fill keep shadow-side-Ozzie-and-Harriet Christmas alternately hilarious, comfortable warm.<br /><br />This movie kind jump get popcorn, get back, everyone wants back show missed.<br /><br />This happy film, all, leaves feeling good life, love, family, Christmas Chanel.",
#   'really something everyone.'],
#  ["What's negative comments?",
#   "seen film first time tonight, say good holiday comedy sure brighten lonely person's day.",
#   'saw Drew (Ben Affleck) might end spending holidays alone, wanted cry.',
#   'see movie want know why.',
#   'Also, even though liked Tom (James Gandolfini) Alicia (Christina Applegate) awhile, ask me, real snobs.',
#   'However, film make smile feel good inside.',
#   "wrap up, I'd like say Mike Mitchell scored pure holiday hit.",
#   "Now, conclusion, highly recommend good holiday comedy sure brighten lonely person's day Ben Affleck Christina Applegate fan seen it."],
#  ['Cary Grant Myrna Loy perfectly cast middle class couple want build house dreams.',
#   'starts reasonable plans expectations, blown bits countless complications explosion original budget.<br /><br />There many great laughs (even story somewhat thin) sure entertain fans stars late 1940s Hollywood comedy style.',
#   'definite highlight comes contractor goes run expenses, must sounded quite excessive 1948 audience.',
#   'makes exit, assures client (Grant) perhaps could achieve reduction $100.00 total...or least $50.00...but certainly $25.00.',
#   'Hilarious!'],
#  ['Come people.',
#   'movie better 4. see happening...wealthy people done crazier things this.',
#   'funny.<br /><br />I watch comedy entertained, escape pressures world short while, take anything seriously.',
#   'movie fully suits purpose.',
#   'judge movie merits compare Surviving Christmas Blazing Saddles.',
#   'watched totally dysfunctional people grow caring, likable individuals could easily live street home.',
#   'remain list "favorite.....must watch holiday season".',
#   'want fun 90 minutes, watch one.'],
#  ['survive Surviving Christmas.',
#   'thought television version bit edited way down.',
#   'like Ben Afleck.',
#   'plays Drew Johnson, family-less adult, willing pay complete strangers.',
#   "Valcos starring James Gandolfini Catherine O'Hara parents Christina Applegate Lisa Valco, daughter.",
#   'Drew lonely around holidays family rents family Chicago suburbs quarter million dollars.',
#   "Bill Macy best remember playing Maude's husband Arthur hired play Duda, grandfather.",
#   'whole situation comes crashing down, truth painful.',
#   'Valcos household crumbling apart Drew situation.',
#   "Drew's rich girlfriend parents make surprising visit.",
#   "can't buy wish for!",
#   'acting writing mediocre first rate cast pulls final scene.'],
#  ["What's like movie?",
#   'Every year know going get one two yule tide movies Christmas time going terrible.',
#   'movie definitely fresh new idea pulled pretty well.',
#   'funny take rich young guy paying family simulate real Christmas him.',
#   "good money like can't fun things it.",
#   'win-win situation.',
#   'regular family gets six figures rich guy gets experience Christmas like imagined.',
#   'if.<br /><br />Drew Latham (Ben Affleck) incredibly difficult deal riot see family reluctantly comply absurd demands.',
#   'fun funny movie.'],
#  ['good thing rented movie seeing viewer rating site.',
#   'wonderful movie adding Christmas selection.',
#   'cast wonderfully chosen Ben Affleck plays good leading role.',
#   'would tell viewers seen movie go ahead buy it.',
#   'rate right Christmas vacation.',
#   'movie funny well written Ben plays eccentric rich executive well.',
#   'things says would imagine person much money act.',
#   'movie much funnier Santa Claus Christmas Kranks.',
#   "Plus good story line teaches true meaning Christmas can't buy love money."],
#  ['reservations movie, figured would usual bill fare --- formula movie Christmas.',
#   'middle heat wave late June, decided give shot anyway, maybe would see snow.<br /><br />This movie turned one laugh another.',
#   'Ben Affleck believable character, real star one James Gandofini.',
#   'delivered lines real wit made great "dad".<br /><br />If want enjoyable couple hours, definitely check one out.'],
#  ['Surviving Christmas surprisingly funny movie especially considering bad publicity first released.',
#   'Ben Affleck funny obnoxious millionaire pays family occupies childhood home family Christmas.',
#   'drives family crazy overindulgence Christmas cheer.',
#   'Ben Affleck fan past (though like Daredevil Paycheck) well cast role.',
#   "also like Christina Applegate daughter family can't stand Affleck's character first.",
#   'Sure see movie going care.',
#   'Ignore critics say rent movie funnier lot Christmas movies.'],
#  ['first think Ben Affleck could really pull funny Christmas movie,, boy wrong, daughter invited watch disappointed all.',
#   "James Gandolfini funny,, really liked Christina Appelagate, Catherine O' Hara good too, storyline really sold me,, mean,, put family,, table people hardly see twice year,, probably get along anyway,, really need much alcohol system stand deal Christmas,, thought premise good there, buying family 250000 dollars, little far fetched side,, turned work pretty good me,, cause riot way through, shows class struggle different families.",
#   "lot's funny moments, including embarrassing stuff computer teenage boy.",
#   'loved movie watch next Christmas sooner daughter wants too.'],
#  ["would expect film titled 'Surviving Christmas'and presented 'festive fun', something like Ghandi English patient?",
#   'lots things love film, funny, well cast superbly written.',
#   'came film Kaplan/Elfort fan dubious read plot, sounded ridiculous.',
#   'film come across like Affleck (as Drew Latham) plays part perfectly, one minute child-like adult, next mature man realises gained everything life apart really wants.',
#   'fact see Latham grow film, encounters problems envies realises lives good, sees lot bad.<br /><br />This film fewer weak dud scenes many comedies seen.',
#   'Comedy much harder type drama, either works comedy writers get correct every time.I particularly loved drama scene, family take reading parts written Latham .',
#   'pleasure reaction Tom Valco (James Gandolfini) comments Brian Valco (Josh Zuckerman).',
#   'dilemma greedy Tom Valco bite tongue, wear silly hats sing Christmas tree order earn prize money keeps film moving along well.<br /><br />The addition daughter Alicia (Christina Applegate) story brings delightful romantic angle, Christmas film?',
#   "course corny contrived; he's rich handsome, beautiful single, inevitably Afflect end falling together snow finding face face.",
#   'Great!',
#   "One thing would liked use festive music boost atmosphere can't really complain.",
#   'got wanted.'],
#  ['movie bad heard.',
#   'enjoyable, funny love revolves around holiday season.',
#   'totally mood Christmas shop listen holiday music.',
#   'movie comes DVD take place Christmas Vacation collection.',
#   'movie watch every year Thanksgiving get mood best time year.',
#   "heard Ben's character bit crazy think adds movie serious time.",
#   'Take it, Christmas comedy love twist.',
#   'enjoyed it.',
#   'No, Titanic make heart pound anticipation bring laugh two.',
#   'go laugh good time:)'],
#  ['laughed hard movie face hurt.',
#   'Ben Affleck hilarious reminded pretty boy Jack Black role.',
#   'Gandolfini gives typical performance.',
#   'entire cast funny, story pretty good comic moments awesome.',
#   'went movie expecting much perhaps surprised come flick thoroughly pleased facially exhausted.',
#   'would recommend movie anyone enjoys comedy, identify loneliness holidays and/or putting relatives.',
#   'best part film (to anyway) subtle bits humor caught completely guard laughing long rest audience stopped.',
#   'Namely, scene involving lighting Christmas tree.',
#   'Go see good laugh!'],
#  ['movie made 1948, still rings true today.',
#   'Very, funny.',
#   'begins family wanting buy little place country "builds" there.',
#   'Anyone ever built house, find movie endearing.',
#   'Great cast.',
#   'Cary Grant Myrna Lloyd delightful film.',
#   "classic black white film reflects grand style 40's....clothing, architecture family life.",
#   "Many references made cost things, comparisons today's costs pretty amazing.",
#   "can't imagine anyone enjoying movie completely.",
#   'surprised number middle aged people never heard it.',
#   'true classic.'],
#  ["`Europa' (or, also known, `Zentropa') one visually stunning films ever seen.",
#   'blend grayscale colour photography near seamless... true feast eyes.',
#   "picture contender 1991's Golden Palm Canners.",
#   'award went Barton Fink (by Coen brothers); film stylistically similar Zentropa.',
#   "Here's exercise class: rent films judge yourself."],
#  ...]

# %%
data = data.assign(sentence = sent)
data.head()
# Out:
#    row_Number                                               text  polarity  \
# 0           0  Bromwell High cartoon comedy. ran time program...         1
# 1           1  Homelessness (or Houselessness George Carlin s...         1
# 2           2  Brilliant over-acting Lesley Ann Warren. Best ...         1
# 3           3  easily underrated film inn Brooks cannon. Sure...         1
# 4           4  typical Mel Brooks film. much less slapstick m...         1
#
#                                             sentence
# 0  [Bromwell High cartoon comedy., ran time progr...
# 1  [Homelessness (or Houselessness George Carlin ...
# 2  [Brilliant over-acting Lesley Ann Warren., Bes...
# 3  [easily underrated film inn Brooks cannon., Su...
# 4  [typical Mel Brooks film., much less slapstick...

# %%
words = []
tokenizer = RegexpTokenizer("[\w']+")
for i in range(0,len(sent)):
    for sentence in sent[i]:
        for w in tokenizer.tokenize(sentence):
            words.append(w)
words
# Out:
# ['Bromwell',
#  'High',
#  'cartoon',
#  'comedy',
#  'ran',
#  'time',
#  'programs',
#  'school',
#  'life',
#  'Teachers',
#  '35',
#  'years',
#  'teaching',
#  'profession',
#  'lead',
#  'believe',
#  'Bromwell',
#  "High's",
#  'satire',
#  'much',
#  'closer',
#  'reality',
#  'Teachers',
#  'scramble',
#  'survive',
#  'financially',
#  'insightful',
#  'students',
#  'see',
#  'right',
#  'pathetic',
#  "teachers'",
#  'pomp',
#  'pettiness',
#  'whole',
#  'situation',
#  'remind',
#  'schools',
#  'knew',
#  'students',
#  'saw',
#  'episode',
#  'student',
#  'repeatedly',
#  'tried',
#  'burn',
#  'school',
#  'immediately',
#  'recalled',
#  'High',
#  'classic',
#  'line',
#  'INSPECTOR',
#  "I'm",
#  'sack',
#  'one',
#  'teachers',
#  'STUDENT',
#  'Welcome',
#  'Bromwell',
#  'High',
#  'expect',
#  'many',
#  'adults',
#  'age',
#  'think',
#  'Bromwell',
#  'High',
#  'far',
#  'fetched',
#  'pity',
#  "isn't",
#  'Homelessness',
#  'or',
#  'Houselessness',
#  'George',
#  'Carlin',
#  'stated',
#  'issue',
#  'years',
#  'never',
#  'plan',
#  'help',
#  'street',
#  'considered',
#  'human',
#  'everything',
#  'going',
#  'school',
#  'work',
#  'vote',
#  'matter',
#  'people',
#  'think',
#  'homeless',
#  'lost',
#  'cause',
#  'worrying',
#  'things',
#  'racism',
#  'war',
#  'Iraq',
#  'pressuring',
#  'kids',
#  'succeed',
#  'technology',
#  'elections',
#  'inflation',
#  'worrying',
#  "they'll",
#  'next',
#  'end',
#  'streets',
#  'br',
#  'br',
#  'But',
#  'given',
#  'bet',
#  'live',
#  'streets',
#  'month',
#  'without',
#  'luxuries',
#  'home',
#  'entertainment',
#  'sets',
#  'bathroom',
#  'pictures',
#  'wall',
#  'computer',
#  'everything',
#  'treasure',
#  'see',
#  'like',
#  'homeless',
#  'Goddard',
#  "Bolt's",
#  'lesson',
#  'br',
#  'br',
#  'Mel',
#  'Brooks',
#  'who',
#  'directs',
#  'stars',
#  'Bolt',
#  'plays',
#  'rich',
#  'man',
#  'everything',
#  'world',
#  'deciding',
#  'make',
#  'bet',
#  'sissy',
#  'rival',
#  'Jeffery',
#  'Tambor',
#  'see',
#  'live',
#  'streets',
#  'thirty',
#  'days',
#  'without',
#  'luxuries',
#  'Bolt',
#  'succeeds',
#  'wants',
#  'future',
#  'project',
#  'making',
#  'buildings',
#  "bet's",
#  'Bolt',
#  'thrown',
#  'street',
#  'bracelet',
#  'leg',
#  'monitor',
#  'every',
#  'move',
#  "can't",
#  'step',
#  'sidewalk',
#  "He's",
#  'given',
#  'nickname',
#  'Pepto',
#  'vagrant',
#  'written',
#  'forehead',
#  'Bolt',
#  'meets',
#  'characters',
#  'including',
#  'woman',
#  'name',
#  'Molly',
#  'Lesley',
#  'Ann',
#  'Warren',
#  'ex',
#  'dancer',
#  'got',
#  'divorce',
#  'losing',
#  'home',
#  'pals',
#  'Sailor',
#  'Howard',
#  'Morris',
#  'Fumes',
#  'Teddy',
#  'Wilson',
#  'already',
#  'used',
#  'streets',
#  "They're",
#  'survivors',
#  'Bolt',
#  "isn't",
#  "He's",
#  'used',
#  'reaching',
#  'mutual',
#  'agreements',
#  'like',
#  'rich',
#  'fight',
#  'flight',
#  'kill',
#  'killed',
#  'br',
#  'br',
#  'While',
#  'love',
#  'connection',
#  'Molly',
#  'Bolt',
#  'necessary',
#  'plot',
#  'found',
#  'Life',
#  'Stinks',
#  'one',
#  'Mel',
#  "Brooks'",
#  'observant',
#  'films',
#  'prior',
#  'comedy',
#  'shows',
#  'tender',
#  'side',
#  'compared',
#  'slapstick',
#  'work',
#  'Blazing',
#  'Saddles',
#  'Young',
#  'Frankenstein',
#  'Spaceballs',
#  'matter',
#  'show',
#  'like',
#  'something',
#  'valuable',
#  'losing',
#  'next',
#  'day',
#  'hand',
#  'making',
#  'stupid',
#  'bet',
#  'like',
#  'rich',
#  'people',
#  'know',
#  'money',
#  'Maybe',
#  'give',
#  'homeless',
#  'instead',
#  'using',
#  'like',
#  'Monopoly',
#  'money',
#  'br',
#  'br',
#  'Or',
#  'maybe',
#  'film',
#  'inspire',
#  'help',
#  'others',
#  'Brilliant',
#  'over',
#  'acting',
#  'Lesley',
#  'Ann',
#  'Warren',
#  'Best',
#  'dramatic',
#  'hobo',
#  'lady',
#  'ever',
#  'seen',
#  'love',
#  'scenes',
#  'clothes',
#  'warehouse',
#  'second',
#  'none',
#  'corn',
#  'face',
#  'classic',
#  'good',
#  'anything',
#  'Blazing',
#  'Saddles',
#  'take',
#  'lawyers',
#  'also',
#  'superb',
#  'accused',
#  'turncoat',
#  'selling',
#  'boss',
#  'dishonest',
#  'lawyer',
#  'Pepto',
#  'Bolt',
#  'shrugs',
#  'indifferently',
#  "I'm",
#  'lawyer',
#  'says',
#  'Three',
#  'funny',
#  'words',
#  'Jeffrey',
#  'Tambor',
#  'favorite',
#  'later',
#  'Larry',
#  'Sanders',
#  'show',
#  'fantastic',
#  'mad',
#  'millionaire',
#  'wants',
#  'crush',
#  'ghetto',
#  'character',
#  'malevolent',
#  'usual',
#  'hospital',
#  'scene',
#  'scene',
#  'homeless',
#  'invade',
#  'demolition',
#  'site',
#  'all',
#  'time',
#  'classics',
#  'Look',
#  'legs',
#  'scene',
#  'two',
#  'big',
#  'diggers',
#  'fighting',
#  'one',
#  'bleeds',
#  'movie',
#  'gets',
#  'better',
#  'time',
#  'see',
#  'which',
#  'quite',
#  'often',
#  'easily',
#  'underrated',
#  'film',
#  'inn',
#  'Brooks',
#  'cannon',
#  'Sure',
#  'flawed',
#  'give',
#  'realistic',
#  'view',
#  'homelessness',
#  'unlike',
#  'say',
#  'Citizen',
#  'Kane',
#  'gave',
#  'realistic',
#  'view',
#  'lounge',
#  'singers',
#  'Titanic',
#  'gave',
#  'realistic',
#  'view',
#  'Italians',
#  'IDIOTS',
#  'Many',
#  'jokes',
#  'fall',
#  'flat',
#  'still',
#  'film',
#  'lovable',
#  'way',
#  'many',
#  'comedies',
#  'not',
#  'pull',
#  'story',
#  'traditionally',
#  'reviled',
#  'members',
#  'society',
#  'truly',
#  'impressive',
#  'Fisher',
#  'King',
#  'crap',
#  'either',
#  'complaint',
#  'Brooks',
#  'cast',
#  'someone',
#  'else',
#  'lead',
#  'I',
#  'love',
#  'Mel',
#  'Director',
#  'Writer',
#  'much',
#  'lead',
#  'typical',
#  'Mel',
#  'Brooks',
#  'film',
#  'much',
#  'less',
#  'slapstick',
#  'movies',
#  'actually',
#  'plot',
#  'followable',
#  'Leslie',
#  'Ann',
#  'Warren',
#  'made',
#  'movie',
#  'fantastic',
#  'under',
#  'rated',
#  'actress',
#  'moments',
#  'could',
#  'fleshed',
#  'bit',
#  'more',
#  'scenes',
#  'could',
#  'probably',
#  'cut',
#  'make',
#  'room',
#  'so',
#  'all',
#  'worth',
#  'price',
#  'rent',
#  'see',
#  'it',
#  'acting',
#  'good',
#  'overall',
#  'Brooks',
#  'good',
#  'job',
#  'without',
#  'characteristic',
#  'speaking',
#  'directly',
#  'audience',
#  'Again',
#  'Warren',
#  'best',
#  'actor',
#  'movie',
#  'Fume',
#  'Sailor',
#  'played',
#  'parts',
#  'well',
#  'comedic',
#  'Robin',
#  'Williams',
#  'quirky',
#  'insane',
#  'Robin',
#  'Williams',
#  'recent',
#  'thriller',
#  'fame',
#  'hybrid',
#  'classic',
#  'drama',
#  'without',
#  'over',
#  'dramatization',
#  'mixed',
#  "Robin's",
#  'new',
#  'love',
#  'thriller',
#  'thriller',
#  'per',
#  'se',
#  'mystery',
#  'suspense',
#  'vehicle',
#  'Williams',
#  'attempts',
#  'locate',
#  'sick',
#  'boy',
#  'keeper',
#  'br',
#  'br',
#  'Also',
#  'starring',
#  'Sandra',
#  'Oh',
#  'Rory',
#  'Culkin',
#  'Suspense',
#  'Drama',
#  'plays',
#  'pretty',
#  'much',
#  'like',
#  'news',
#  'report',
#  "William's",
#  'character',
#  'gets',
#  'close',
#  'achieving',
#  'goal',
#  'br',
#  'br',
#  'I',
#  'must',
#  'say',
#  'highly',
#  'entertained',
#  'though',
#  'movie',
#  'fails',
#  'teach',
#  'guide',
#  'inspect',
#  'amuse',
#  'felt',
#  'like',
#  'watching',
#  'guy',
#  'Williams',
#  'actually',
#  'performing',
#  'actions',
#  'third',
#  'person',
#  'perspective',
#  'words',
#  'felt',
#  'real',
#  'able',
#  'subscribe',
#  'premise',
#  'story',
#  'br',
#  'br',
#  'All',
#  'all',
#  'worth',
#  'watch',
#  'though',
#  'definitely',
#  'Friday',
#  'Saturday',
#  'night',
#  'fare',
#  'br',
#  'br',
#  'It',
#  'rates',
#  '7',
#  '7',
#  '10',
#  'from',
#  'br',
#  'br',
#  'the',
#  'Fiend',
#  'Yes',
#  'art',
#  'successfully',
#  'make',
#  'slow',
#  'paced',
#  'thriller',
#  'br',
#  'br',
#  'The',
#  'story',
#  'unfolds',
#  'nice',
#  'volumes',
#  'even',
#  'notice',
#  'happening',
#  'br',
#  'br',
#  'Fine',
#  'performance',
#  'Robin',
#  'Williams',
#  'sexuality',
#  'angles',
#  'film',
#  'seem',
#  'unnecessary',
#  'probably',
#  'affect',
#  'much',
#  'enjoy',
#  'film',
#  'However',
#  'core',
#  'plot',
#  'engaging',
#  'movie',
#  'rush',
#  'onto',
#  'still',
#  'grips',
#  'enough',
#  'keep',
#  'wondering',
#  'direction',
#  'good',
#  'Use',
#  'lights',
#  'achieve',
#  'desired',
#  'affects',
#  'suspense',
#  'unexpectedness',
#  'good',
#  'br',
#  'br',
#  'Very',
#  'nice',
#  '1',
#  'time',
#  'watch',
#  'looking',
#  'lay',
#  'back',
#  'hear',
#  'thrilling',
#  'short',
#  'story',
#  'critically',
#  'acclaimed',
#  'psychological',
#  'thriller',
#  'based',
#  'true',
#  'events',
#  'Gabriel',
#  'Robin',
#  'Williams',
#  'celebrated',
#  'writer',
#  'late',
#  'night',
#  'talk',
#  'show',
#  'host',
#  'becomes',
#  'captivated',
#  'harrowing',
#  'story',
#  'young',
#  'listener',
#  'adoptive',
#  'mother',
#  'Toni',
#  'Collette',
#  'troubling',
#  'questions',
#  'arise',
#  "boy's",
#  'story',
#  'however',
#  'Gabriel',
#  'finds',
#  'drawn',
#  'widening',
#  'mystery',
#  'hides',
#  'deadly',
#  'secret',
#  'according',
#  "film's",
#  'official',
#  'synopsis',
#  'br',
#  'br',
#  'You',
#  'really',
#  'STOP',
#  'reading',
#  'comments',
#  'watch',
#  'film',
#  'NOW',
#  'br',
#  'br',
#  'The',
#  'How',
#  'lose',
#  'leg',
#  'ending',
#  'Ms',
#  'Collette',
#  'planning',
#  'new',
#  'life',
#  'chopped',
#  'off',
#  'sent',
#  'deleted',
#  'scenes',
#  'land',
#  'overkill',
#  'true',
#  'nature',
#  'physical',
#  'mental',
#  'ailments',
#  'obvious',
#  'time',
#  'Mr',
#  'Williams',
#  'returns',
#  'New',
#  'York',
#  'Possibly',
#  'blindness',
#  'could',
#  'question',
#  'revelation',
#  'could',
#  'made',
#  'certain',
#  'either',
#  'highway',
#  'video',
#  'tape',
#  'scenes',
#  'film',
#  'would',
#  'benefit',
#  're',
#  'editing',
#  "director's",
#  'cut',
#  'br',
#  'br',
#  'Williams',
#  'Bobby',
#  'Cannavale',
#  'as',
#  'Jess',
#  'seem',
#  'initially',
#  'believable',
#  'couple',
#  'scene',
#  'two',
#  'establishing',
#  'relationship',
#  'might',
#  'helped',
#  'set',
#  'stage',
#  'Otherwise',
#  'cast',
#  'exemplary',
#  'Williams',
#  'offers',
#  'exceptionally',
#  'strong',
#  'characterization',
#  'gay',
#  'impersonation',
#  'Sandra',
#  'Oh',
#  'as',
#  'Anna',
#  'Joe',
#  'Morton',
#  'as',
#  'Ashe',
#  'Rory',
#  'Culkin',
#  'Pete',
#  'Logand',
#  'perfect',
#  'br',
#  'br',
#  'Best',
#  'all',
#  "Collette's",
#  'Donna',
#  'belongs',
#  'creepy',
#  'hall',
#  'fame',
#  'Ms',
#  'Oh',
#  'correct',
#  'saying',
#  'Collette',
#  'might',
#  'be',
#  'you',
#  'know',
#  'like',
#  'guy',
#  "'Psycho'",
#  'several',
#  'years',
#  'organizations',
#  'giving',
#  'acting',
#  'awards',
#  'seemed',
#  'reach',
#  'women',
#  'due',
#  'slighter',
#  'dispersion',
#  'roles',
#  'certainly',
#  'could',
#  'noticed',
#  'Collette',
#  'award',
#  'consideration',
#  'good',
#  'And',
#  'director',
#  'Patrick',
#  'Stettner',
#  'definitely',
#  'evokes',
#  'Hitchcock',
#  'even',
#  'makes',
#  'getting',
#  'sandwich',
#  'vending',
#  'machine',
#  'suspenseful',
#  'br',
#  'br',
#  'Finally',
#  'writers',
#  'Stettner',
#  'Armistead',
#  'Maupin',
#  'Terry',
#  'Anderson',
#  'deserve',
#  'gratitude',
#  'flight',
#  'attendants',
#  'everywhere',
#  'br',
#  'br',
#  'Night',
#  'Listener',
#  '1',
#  '21',
#  '06',
#  'Patrick',
#  'Stettner',
#  'Robin',
#  'Williams',
#  'Toni',
#  'Collette',
#  'Sandra',
#  'Oh',
#  'Rory',
#  'Culkin',
#  'NIGHT',
#  'LISTENER',
#  '2006',
#  '1',
#  '2',
#  'Robin',
#  'Williams',
#  'Toni',
#  'Collette',
#  'Bobby',
#  'Cannavale',
#  'Rory',
#  'Culkin',
#  'Joe',
#  'Morton',
#  'Sandra',
#  'Oh',
#  'John',
#  'Cullum',
#  'Lisa',
#  'Emery',
#  'Becky',
#  'Ann',
#  'Baker',
#  'Dir',
#  'Patrick',
#  'Stettner',
#  'br',
#  'br',
#  'Hitchcockian',
#  'suspenser',
#  'gives',
#  'Williams',
#  'stand',
#  'out',
#  'low',
#  'key',
#  'performance',
#  'br',
#  'br',
#  'What',
#  'celebrities',
#  'fans',
#  'near',
#  'paranoia',
#  'one',
#  'associates',
#  'almost',
#  'norm',
#  'br',
#  'br',
#  'In',
#  'latest',
#  'derange',
#  'fan',
#  'scenario',
#  'based',
#  'true',
#  'events',
#  'less',
#  'Williams',
#  'stars',
#  'talk',
#  'radio',
#  'personality',
#  'named',
#  'Gabriel',
#  'one',
#  'reads',
#  'stories',
#  "he's",
#  'penned',
#  'airwaves',
#  'accumulated',
#  'interesting',
#  'fan',
#  'form',
#  'young',
#  'boy',
#  'named',
#  ...]

# %% [markdown]
# ## Stemming words

# %%
stemmer = PorterStemmer() 
stemed_word = []
for word in words:
    word = stemmer.stem(word)
    stemed_word.append(word)
stemed_word
# Out:
# ['bromwel',
#  'high',
#  'cartoon',
#  'comedi',
#  'ran',
#  'time',
#  'program',
#  'school',
#  'life',
#  'teacher',
#  '35',
#  'year',
#  'teach',
#  'profess',
#  'lead',
#  'believ',
#  'bromwel',
#  "high'",
#  'satir',
#  'much',
#  'closer',
#  'realiti',
#  'teacher',
#  'scrambl',
#  'surviv',
#  'financi',
#  'insight',
#  'student',
#  'see',
#  'right',
#  'pathet',
#  "teachers'",
#  'pomp',
#  'petti',
#  'whole',
#  'situat',
#  'remind',
#  'school',
#  'knew',
#  'student',
#  'saw',
#  'episod',
#  'student',
#  'repeatedli',
#  'tri',
#  'burn',
#  'school',
#  'immedi',
#  'recal',
#  'high',
#  'classic',
#  'line',
#  'inspector',
#  "i'm",
#  'sack',
#  'one',
#  'teacher',
#  'student',
#  'welcom',
#  'bromwel',
#  'high',
#  'expect',
#  'mani',
#  'adult',
#  'age',
#  'think',
#  'bromwel',
#  'high',
#  'far',
#  'fetch',
#  'piti',
#  "isn't",
#  'homeless',
#  'or',
#  'houseless',
#  'georg',
#  'carlin',
#  'state',
#  'issu',
#  'year',
#  'never',
#  'plan',
#  'help',
#  'street',
#  'consid',
#  'human',
#  'everyth',
#  'go',
#  'school',
#  'work',
#  'vote',
#  'matter',
#  'peopl',
#  'think',
#  'homeless',
#  'lost',
#  'caus',
#  'worri',
#  'thing',
#  'racism',
#  'war',
#  'iraq',
#  'pressur',
#  'kid',
#  'succeed',
#  'technolog',
#  'elect',
#  'inflat',
#  'worri',
#  "they'll",
#  'next',
#  'end',
#  'street',
#  'br',
#  'br',
#  'but',
#  'given',
#  'bet',
#  'live',
#  'street',
#  'month',
#  'without',
#  'luxuri',
#  'home',
#  'entertain',
#  'set',
#  'bathroom',
#  'pictur',
#  'wall',
#  'comput',
#  'everyth',
#  'treasur',
#  'see',
#  'like',
#  'homeless',
#  'goddard',
#  "bolt'",
#  'lesson',
#  'br',
#  'br',
#  'mel',
#  'brook',
#  'who',
#  'direct',
#  'star',
#  'bolt',
#  'play',
#  'rich',
#  'man',
#  'everyth',
#  'world',
#  'decid',
#  'make',
#  'bet',
#  'sissi',
#  'rival',
#  'jefferi',
#  'tambor',
#  'see',
#  'live',
#  'street',
#  'thirti',
#  'day',
#  'without',
#  'luxuri',
#  'bolt',
#  'succe',
#  'want',
#  'futur',
#  'project',
#  'make',
#  'build',
#  "bet'",
#  'bolt',
#  'thrown',
#  'street',
#  'bracelet',
#  'leg',
#  'monitor',
#  'everi',
#  'move',
#  "can't",
#  'step',
#  'sidewalk',
#  "he'",
#  'given',
#  'nicknam',
#  'pepto',
#  'vagrant',
#  'written',
#  'forehead',
#  'bolt',
#  'meet',
#  'charact',
#  'includ',
#  'woman',
#  'name',
#  'molli',
#  'lesley',
#  'ann',
#  'warren',
#  'ex',
#  'dancer',
#  'got',
#  'divorc',
#  'lose',
#  'home',
#  'pal',
#  'sailor',
#  'howard',
#  'morri',
#  'fume',
#  'teddi',
#  'wilson',
#  'alreadi',
#  'use',
#  'street',
#  "they'r",
#  'survivor',
#  'bolt',
#  "isn't",
#  "he'",
#  'use',
#  'reach',
#  'mutual',
#  'agreement',
#  'like',
#  'rich',
#  'fight',
#  'flight',
#  'kill',
#  'kill',
#  'br',
#  'br',
#  'while',
#  'love',
#  'connect',
#  'molli',
#  'bolt',
#  'necessari',
#  'plot',
#  'found',
#  'life',
#  'stink',
#  'one',
#  'mel',
#  "brooks'",
#  'observ',
#  'film',
#  'prior',
#  'comedi',
#  'show',
#  'tender',
#  'side',
#  'compar',
#  'slapstick',
#  'work',
#  'blaze',
#  'saddl',
#  'young',
#  'frankenstein',
#  'spacebal',
#  'matter',
#  'show',
#  'like',
#  'someth',
#  'valuabl',
#  'lose',
#  'next',
#  'day',
#  'hand',
#  'make',
#  'stupid',
#  'bet',
#  'like',
#  'rich',
#  'peopl',
#  'know',
#  'money',
#  'mayb',
#  'give',
#  'homeless',
#  'instead',
#  'use',
#  'like',
#  'monopoli',
#  'money',
#  'br',
#  'br',
#  'Or',
#  'mayb',
#  'film',
#  'inspir',
#  'help',
#  'other',
#  'brilliant',
#  'over',
#  'act',
#  'lesley',
#  'ann',
#  'warren',
#  'best',
#  'dramat',
#  'hobo',
#  'ladi',
#  'ever',
#  'seen',
#  'love',
#  'scene',
#  'cloth',
#  'warehous',
#  'second',
#  'none',
#  'corn',
#  'face',
#  'classic',
#  'good',
#  'anyth',
#  'blaze',
#  'saddl',
#  'take',
#  'lawyer',
#  'also',
#  'superb',
#  'accus',
#  'turncoat',
#  'sell',
#  'boss',
#  'dishonest',
#  'lawyer',
#  'pepto',
#  'bolt',
#  'shrug',
#  'indiffer',
#  "i'm",
#  'lawyer',
#  'say',
#  'three',
#  'funni',
#  'word',
#  'jeffrey',
#  'tambor',
#  'favorit',
#  'later',
#  'larri',
#  'sander',
#  'show',
#  'fantast',
#  'mad',
#  'millionair',
#  'want',
#  'crush',
#  'ghetto',
#  'charact',
#  'malevol',
#  'usual',
#  'hospit',
#  'scene',
#  'scene',
#  'homeless',
#  'invad',
#  'demolit',
#  'site',
#  'all',
#  'time',
#  'classic',
#  'look',
#  'leg',
#  'scene',
#  'two',
#  'big',
#  'digger',
#  'fight',
#  'one',
#  'bleed',
#  'movi',
#  'get',
#  'better',
#  'time',
#  'see',
#  'which',
#  'quit',
#  'often',
#  'easili',
#  'underr',
#  'film',
#  'inn',
#  'brook',
#  'cannon',
#  'sure',
#  'flaw',
#  'give',
#  'realist',
#  'view',
#  'homeless',
#  'unlik',
#  'say',
#  'citizen',
#  'kane',
#  'gave',
#  'realist',
#  'view',
#  'loung',
#  'singer',
#  'titan',
#  'gave',
#  'realist',
#  'view',
#  'italian',
#  'idiot',
#  'mani',
#  'joke',
#  'fall',
#  'flat',
#  'still',
#  'film',
#  'lovabl',
#  'way',
#  'mani',
#  'comedi',
#  'not',
#  'pull',
#  'stori',
#  'tradit',
#  'revil',
#  'member',
#  'societi',
#  'truli',
#  'impress',
#  'fisher',
#  'king',
#  'crap',
#  'either',
#  'complaint',
#  'brook',
#  'cast',
#  'someon',
#  'els',
#  'lead',
#  'I',
#  'love',
#  'mel',
#  'director',
#  'writer',
#  'much',
#  'lead',
#  'typic',
#  'mel',
#  'brook',
#  'film',
#  'much',
#  'less',
#  'slapstick',
#  'movi',
#  'actual',
#  'plot',
#  'follow',
#  'lesli',
#  'ann',
#  'warren',
#  'made',
#  'movi',
#  'fantast',
#  'under',
#  'rate',
#  'actress',
#  'moment',
#  'could',
#  'flesh',
#  'bit',
#  'more',
#  'scene',
#  'could',
#  'probabl',
#  'cut',
#  'make',
#  'room',
#  'so',
#  'all',
#  'worth',
#  'price',
#  'rent',
#  'see',
#  'it',
#  'act',
#  'good',
#  'overal',
#  'brook',
#  'good',
#  'job',
#  'without',
#  'characterist',
#  'speak',
#  'directli',
#  'audienc',
#  'again',
#  'warren',
#  'best',
#  'actor',
#  'movi',
#  'fume',
#  'sailor',
#  'play',
#  'part',
#  'well',
#  'comed',
#  'robin',
#  'william',
#  'quirki',
#  'insan',
#  'robin',
#  'william',
#  'recent',
#  'thriller',
#  'fame',
#  'hybrid',
#  'classic',
#  'drama',
#  'without',
#  'over',
#  'dramat',
#  'mix',
#  "robin'",
#  'new',
#  'love',
#  'thriller',
#  'thriller',
#  'per',
#  'se',
#  'mysteri',
#  'suspens',
#  'vehicl',
#  'william',
#  'attempt',
#  'locat',
#  'sick',
#  'boy',
#  'keeper',
#  'br',
#  'br',
#  'also',
#  'star',
#  'sandra',
#  'Oh',
#  'rori',
#  'culkin',
#  'suspens',
#  'drama',
#  'play',
#  'pretti',
#  'much',
#  'like',
#  'news',
#  'report',
#  "william'",
#  'charact',
#  'get',
#  'close',
#  'achiev',
#  'goal',
#  'br',
#  'br',
#  'I',
#  'must',
#  'say',
#  'highli',
#  'entertain',
#  'though',
#  'movi',
#  'fail',
#  'teach',
#  'guid',
#  'inspect',
#  'amus',
#  'felt',
#  'like',
#  'watch',
#  'guy',
#  'william',
#  'actual',
#  'perform',
#  'action',
#  'third',
#  'person',
#  'perspect',
#  'word',
#  'felt',
#  'real',
#  'abl',
#  'subscrib',
#  'premis',
#  'stori',
#  'br',
#  'br',
#  'all',
#  'all',
#  'worth',
#  'watch',
#  'though',
#  'definit',
#  'friday',
#  'saturday',
#  'night',
#  'fare',
#  'br',
#  'br',
#  'It',
#  'rate',
#  '7',
#  '7',
#  '10',
#  'from',
#  'br',
#  'br',
#  'the',
#  'fiend',
#  'ye',
#  'art',
#  'success',
#  'make',
#  'slow',
#  'pace',
#  'thriller',
#  'br',
#  'br',
#  'the',
#  'stori',
#  'unfold',
#  'nice',
#  'volum',
#  'even',
#  'notic',
#  'happen',
#  'br',
#  'br',
#  'fine',
#  'perform',
#  'robin',
#  'william',
#  'sexual',
#  'angl',
#  'film',
#  'seem',
#  'unnecessari',
#  'probabl',
#  'affect',
#  'much',
#  'enjoy',
#  'film',
#  'howev',
#  'core',
#  'plot',
#  'engag',
#  'movi',
#  'rush',
#  'onto',
#  'still',
#  'grip',
#  'enough',
#  'keep',
#  'wonder',
#  'direct',
#  'good',
#  'use',
#  'light',
#  'achiev',
#  'desir',
#  'affect',
#  'suspens',
#  'unexpected',
#  'good',
#  'br',
#  'br',
#  'veri',
#  'nice',
#  '1',
#  'time',
#  'watch',
#  'look',
#  'lay',
#  'back',
#  'hear',
#  'thrill',
#  'short',
#  'stori',
#  'critic',
#  'acclaim',
#  'psycholog',
#  'thriller',
#  'base',
#  'true',
#  'event',
#  'gabriel',
#  'robin',
#  'william',
#  'celebr',
#  'writer',
#  'late',
#  'night',
#  'talk',
#  'show',
#  'host',
#  'becom',
#  'captiv',
#  'harrow',
#  'stori',
#  'young',
#  'listen',
#  'adopt',
#  'mother',
#  'toni',
#  'collett',
#  'troubl',
#  'question',
#  'aris',
#  "boy'",
#  'stori',
#  'howev',
#  'gabriel',
#  'find',
#  'drawn',
#  'widen',
#  'mysteri',
#  'hide',
#  'deadli',
#  'secret',
#  'accord',
#  "film'",
#  'offici',
#  'synopsi',
#  'br',
#  'br',
#  'you',
#  'realli',
#  'stop',
#  'read',
#  'comment',
#  'watch',
#  'film',
#  'now',
#  'br',
#  'br',
#  'the',
#  'how',
#  'lose',
#  'leg',
#  'end',
#  'Ms',
#  'collett',
#  'plan',
#  'new',
#  'life',
#  'chop',
#  'off',
#  'sent',
#  'delet',
#  'scene',
#  'land',
#  'overkil',
#  'true',
#  'natur',
#  'physic',
#  'mental',
#  'ailment',
#  'obviou',
#  'time',
#  'Mr',
#  'william',
#  'return',
#  'new',
#  'york',
#  'possibl',
#  'blind',
#  'could',
#  'question',
#  'revel',
#  'could',
#  'made',
#  'certain',
#  'either',
#  'highway',
#  'video',
#  'tape',
#  'scene',
#  'film',
#  'would',
#  'benefit',
#  're',
#  'edit',
#  "director'",
#  'cut',
#  'br',
#  'br',
#  'william',
#  'bobbi',
#  'cannaval',
#  'as',
#  'jess',
#  'seem',
#  'initi',
#  'believ',
#  'coupl',
#  'scene',
#  'two',
#  'establish',
#  'relationship',
#  'might',
#  'help',
#  'set',
#  'stage',
#  'otherwis',
#  'cast',
#  'exemplari',
#  'william',
#  'offer',
#  'except',
#  'strong',
#  'character',
#  'gay',
#  'imperson',
#  'sandra',
#  'Oh',
#  'as',
#  'anna',
#  'joe',
#  'morton',
#  'as',
#  'ash',
#  'rori',
#  'culkin',
#  'pete',
#  'logand',
#  'perfect',
#  'br',
#  'br',
#  'best',
#  'all',
#  "collette'",
#  'donna',
#  'belong',
#  'creepi',
#  'hall',
#  'fame',
#  'Ms',
#  'Oh',
#  'correct',
#  'say',
#  'collett',
#  'might',
#  'be',
#  'you',
#  'know',
#  'like',
#  'guy',
#  "'psycho'",
#  'sever',
#  'year',
#  'organ',
#  'give',
#  'act',
#  'award',
#  'seem',
#  'reach',
#  'women',
#  'due',
#  'slighter',
#  'dispers',
#  'role',
#  'certainli',
#  'could',
#  'notic',
#  'collett',
#  'award',
#  'consider',
#  'good',
#  'and',
#  'director',
#  'patrick',
#  'stettner',
#  'definit',
#  'evok',
#  'hitchcock',
#  'even',
#  'make',
#  'get',
#  'sandwich',
#  'vend',
#  'machin',
#  'suspens',
#  'br',
#  'br',
#  'final',
#  'writer',
#  'stettner',
#  'armistead',
#  'maupin',
#  'terri',
#  'anderson',
#  'deserv',
#  'gratitud',
#  'flight',
#  'attend',
#  'everywher',
#  'br',
#  'br',
#  'night',
#  'listen',
#  '1',
#  '21',
#  '06',
#  'patrick',
#  'stettner',
#  'robin',
#  'william',
#  'toni',
#  'collett',
#  'sandra',
#  'Oh',
#  'rori',
#  'culkin',
#  'night',
#  'listen',
#  '2006',
#  '1',
#  '2',
#  'robin',
#  'william',
#  'toni',
#  'collett',
#  'bobbi',
#  'cannaval',
#  'rori',
#  'culkin',
#  'joe',
#  'morton',
#  'sandra',
#  'Oh',
#  'john',
#  'cullum',
#  'lisa',
#  'emeri',
#  'becki',
#  'ann',
#  'baker',
#  'dir',
#  'patrick',
#  'stettner',
#  'br',
#  'br',
#  'hitchcockian',
#  'suspens',
#  'give',
#  'william',
#  'stand',
#  'out',
#  'low',
#  'key',
#  'perform',
#  'br',
#  'br',
#  'what',
#  'celebr',
#  'fan',
#  'near',
#  'paranoia',
#  'one',
#  'associ',
#  'almost',
#  'norm',
#  'br',
#  'br',
#  'In',
#  'latest',
#  'derang',
#  'fan',
#  'scenario',
#  'base',
#  'true',
#  'event',
#  'less',
#  'william',
#  'star',
#  'talk',
#  'radio',
#  'person',
#  'name',
#  'gabriel',
#  'one',
#  'read',
#  'stori',
#  "he'",
#  'pen',
#  'airwav',
#  'accumul',
#  'interest',
#  'fan',
#  'form',
#  'young',
#  'boy',
#  'name',
#  ...]

# %%
stemmer.stem("years")
# Out:
# 'year'

# %% [markdown]
# ## Punctuation removal

# %%
replacement_patterns = [(r'won\'t', 'will not'),\
                        (r'can\'t', 'cannot'),\
                        (r'i\'m', 'i am'),\
                        (r'ain\'t', 'is not'),\
                        (r'(\w+)\'ll', '\g<1> will'),\
                        (r'(\w+)n\'t', '\g<1> not'),\
                        (r'(\w+)\'ve', '\g<1> have'),\
                        (r'(\w+)\'s', '\g<1> is'),\
                        (r'(\w+)\'re', '\g<1> are'),\
                        (r'(\w+)\'d', '\g<1> would')]
class RegexpReplacer(object):  
    def __init__(self, patterns=replacement_patterns):    
        self.patterns = [(re.compile(regex), repl) for (regex, repl) in patterns]
    def replace(self, text):    
        s = text 
        for (pattern, repl) in self.patterns:      
            s = re.sub(pattern, repl, s)
        return s

# %%
replacer = RegexpReplacer()
clean_word = []
for word in stemed_word:
    word = replacer.replace(word)
    clean_word.append(word)
clean_word
# Out:
# ['bromwel',
#  'high',
#  'cartoon',
#  'comedi',
#  'ran',
#  'time',
#  'program',
#  'school',
#  'life',
#  'teacher',
#  '35',
#  'year',
#  'teach',
#  'profess',
#  'lead',
#  'believ',
#  'bromwel',
#  "high'",
#  'satir',
#  'much',
#  'closer',
#  'realiti',
#  'teacher',
#  'scrambl',
#  'surviv',
#  'financi',
#  'insight',
#  'student',
#  'see',
#  'right',
#  'pathet',
#  "teachers'",
#  'pomp',
#  'petti',
#  'whole',
#  'situat',
#  'remind',
#  'school',
#  'knew',
#  'student',
#  'saw',
#  'episod',
#  'student',
#  'repeatedli',
#  'tri',
#  'burn',
#  'school',
#  'immedi',
#  'recal',
#  'high',
#  'classic',
#  'line',
#  'inspector',
#  'i am',
#  'sack',
#  'one',
#  'teacher',
#  'student',
#  'welcom',
#  'bromwel',
#  'high',
#  'expect',
#  'mani',
#  'adult',
#  'age',
#  'think',
#  'bromwel',
#  'high',
#  'far',
#  'fetch',
#  'piti',
#  'is not',
#  'homeless',
#  'or',
#  'houseless',
#  'georg',
#  'carlin',
#  'state',
#  'issu',
#  'year',
#  'never',
#  'plan',
#  'help',
#  'street',
#  'consid',
#  'human',
#  'everyth',
#  'go',
#  'school',
#  'work',
#  'vote',
#  'matter',
#  'peopl',
#  'think',
#  'homeless',
#  'lost',
#  'caus',
#  'worri',
#  'thing',
#  'racism',
#  'war',
#  'iraq',
#  'pressur',
#  'kid',
#  'succeed',
#  'technolog',
#  'elect',
#  'inflat',
#  'worri',
#  'they will',
#  'next',
#  'end',
#  'street',
#  'br',
#  'br',
#  'but',
#  'given',
#  'bet',
#  'live',
#  'street',
#  'month',
#  'without',
#  'luxuri',
#  'home',
#  'entertain',
#  'set',
#  'bathroom',
#  'pictur',
#  'wall',
#  'comput',
#  'everyth',
#  'treasur',
#  'see',
#  'like',
#  'homeless',
#  'goddard',
#  "bolt'",
#  'lesson',
#  'br',
#  'br',
#  'mel',
#  'brook',
#  'who',
#  'direct',
#  'star',
#  'bolt',
#  'play',
#  'rich',
#  'man',
#  'everyth',
#  'world',
#  'decid',
#  'make',
#  'bet',
#  'sissi',
#  'rival',
#  'jefferi',
#  'tambor',
#  'see',
#  'live',
#  'street',
#  'thirti',
#  'day',
#  'without',
#  'luxuri',
#  'bolt',
#  'succe',
#  'want',
#  'futur',
#  'project',
#  'make',
#  'build',
#  "bet'",
#  'bolt',
#  'thrown',
#  'street',
#  'bracelet',
#  'leg',
#  'monitor',
#  'everi',
#  'move',
#  'cannot',
#  'step',
#  'sidewalk',
#  "he'",
#  'given',
#  'nicknam',
#  'pepto',
#  'vagrant',
#  'written',
#  'forehead',
#  'bolt',
#  'meet',
#  'charact',
#  'includ',
#  'woman',
#  'name',
#  'molli',
#  'lesley',
#  'ann',
#  'warren',
#  'ex',
#  'dancer',
#  'got',
#  'divorc',
#  'lose',
#  'home',
#  'pal',
#  'sailor',
#  'howard',
#  'morri',
#  'fume',
#  'teddi',
#  'wilson',
#  'alreadi',
#  'use',
#  'street',
#  "they'r",
#  'survivor',
#  'bolt',
#  'is not',
#  "he'",
#  'use',
#  'reach',
#  'mutual',
#  'agreement',
#  'like',
#  'rich',
#  'fight',
#  'flight',
#  'kill',
#  'kill',
#  'br',
#  'br',
#  'while',
#  'love',
#  'connect',
#  'molli',
#  'bolt',
#  'necessari',
#  'plot',
#  'found',
#  'life',
#  'stink',
#  'one',
#  'mel',
#  "brooks'",
#  'observ',
#  'film',
#  'prior',
#  'comedi',
#  'show',
#  'tender',
#  'side',
#  'compar',
#  'slapstick',
#  'work',
#  'blaze',
#  'saddl',
#  'young',
#  'frankenstein',
#  'spacebal',
#  'matter',
#  'show',
#  'like',
#  'someth',
#  'valuabl',
#  'lose',
#  'next',
#  'day',
#  'hand',
#  'make',
#  'stupid',
#  'bet',
#  'like',
#  'rich',
#  'peopl',
#  'know',
#  'money',
#  'mayb',
#  'give',
#  'homeless',
#  'instead',
#  'use',
#  'like',
#  'monopoli',
#  'money',
#  'br',
#  'br',
#  'Or',
#  'mayb',
#  'film',
#  'inspir',
#  'help',
#  'other',
#  'brilliant',
#  'over',
#  'act',
#  'lesley',
#  'ann',
#  'warren',
#  'best',
#  'dramat',
#  'hobo',
#  'ladi',
#  'ever',
#  'seen',
#  'love',
#  'scene',
#  'cloth',
#  'warehous',
#  'second',
#  'none',
#  'corn',
#  'face',
#  'classic',
#  'good',
#  'anyth',
#  'blaze',
#  'saddl',
#  'take',
#  'lawyer',
#  'also',
#  'superb',
#  'accus',
#  'turncoat',
#  'sell',
#  'boss',
#  'dishonest',
#  'lawyer',
#  'pepto',
#  'bolt',
#  'shrug',
#  'indiffer',
#  'i am',
#  'lawyer',
#  'say',
#  'three',
#  'funni',
#  'word',
#  'jeffrey',
#  'tambor',
#  'favorit',
#  'later',
#  'larri',
#  'sander',
#  'show',
#  'fantast',
#  'mad',
#  'millionair',
#  'want',
#  'crush',
#  'ghetto',
#  'charact',
#  'malevol',
#  'usual',
#  'hospit',
#  'scene',
#  'scene',
#  'homeless',
#  'invad',
#  'demolit',
#  'site',
#  'all',
#  'time',
#  'classic',
#  'look',
#  'leg',
#  'scene',
#  'two',
#  'big',
#  'digger',
#  'fight',
#  'one',
#  'bleed',
#  'movi',
#  'get',
#  'better',
#  'time',
#  'see',
#  'which',
#  'quit',
#  'often',
#  'easili',
#  'underr',
#  'film',
#  'inn',
#  'brook',
#  'cannon',
#  'sure',
#  'flaw',
#  'give',
#  'realist',
#  'view',
#  'homeless',
#  'unlik',
#  'say',
#  'citizen',
#  'kane',
#  'gave',
#  'realist',
#  'view',
#  'loung',
#  'singer',
#  'titan',
#  'gave',
#  'realist',
#  'view',
#  'italian',
#  'idiot',
#  'mani',
#  'joke',
#  'fall',
#  'flat',
#  'still',
#  'film',
#  'lovabl',
#  'way',
#  'mani',
#  'comedi',
#  'not',
#  'pull',
#  'stori',
#  'tradit',
#  'revil',
#  'member',
#  'societi',
#  'truli',
#  'impress',
#  'fisher',
#  'king',
#  'crap',
#  'either',
#  'complaint',
#  'brook',
#  'cast',
#  'someon',
#  'els',
#  'lead',
#  'I',
#  'love',
#  'mel',
#  'director',
#  'writer',
#  'much',
#  'lead',
#  'typic',
#  'mel',
#  'brook',
#  'film',
#  'much',
#  'less',
#  'slapstick',
#  'movi',
#  'actual',
#  'plot',
#  'follow',
#  'lesli',
#  'ann',
#  'warren',
#  'made',
#  'movi',
#  'fantast',
#  'under',
#  'rate',
#  'actress',
#  'moment',
#  'could',
#  'flesh',
#  'bit',
#  'more',
#  'scene',
#  'could',
#  'probabl',
#  'cut',
#  'make',
#  'room',
#  'so',
#  'all',
#  'worth',
#  'price',
#  'rent',
#  'see',
#  'it',
#  'act',
#  'good',
#  'overal',
#  'brook',
#  'good',
#  'job',
#  'without',
#  'characterist',
#  'speak',
#  'directli',
#  'audienc',
#  'again',
#  'warren',
#  'best',
#  'actor',
#  'movi',
#  'fume',
#  'sailor',
#  'play',
#  'part',
#  'well',
#  'comed',
#  'robin',
#  'william',
#  'quirki',
#  'insan',
#  'robin',
#  'william',
#  'recent',
#  'thriller',
#  'fame',
#  'hybrid',
#  'classic',
#  'drama',
#  'without',
#  'over',
#  'dramat',
#  'mix',
#  "robin'",
#  'new',
#  'love',
#  'thriller',
#  'thriller',
#  'per',
#  'se',
#  'mysteri',
#  'suspens',
#  'vehicl',
#  'william',
#  'attempt',
#  'locat',
#  'sick',
#  'boy',
#  'keeper',
#  'br',
#  'br',
#  'also',
#  'star',
#  'sandra',
#  'Oh',
#  'rori',
#  'culkin',
#  'suspens',
#  'drama',
#  'play',
#  'pretti',
#  'much',
#  'like',
#  'news',
#  'report',
#  "william'",
#  'charact',
#  'get',
#  'close',
#  'achiev',
#  'goal',
#  'br',
#  'br',
#  'I',
#  'must',
#  'say',
#  'highli',
#  'entertain',
#  'though',
#  'movi',
#  'fail',
#  'teach',
#  'guid',
#  'inspect',
#  'amus',
#  'felt',
#  'like',
#  'watch',
#  'guy',
#  'william',
#  'actual',
#  'perform',
#  'action',
#  'third',
#  'person',
#  'perspect',
#  'word',
#  'felt',
#  'real',
#  'abl',
#  'subscrib',
#  'premis',
#  'stori',
#  'br',
#  'br',
#  'all',
#  'all',
#  'worth',
#  'watch',
#  'though',
#  'definit',
#  'friday',
#  'saturday',
#  'night',
#  'fare',
#  'br',
#  'br',
#  'It',
#  'rate',
#  '7',
#  '7',
#  '10',
#  'from',
#  'br',
#  'br',
#  'the',
#  'fiend',
#  'ye',
#  'art',
#  'success',
#  'make',
#  'slow',
#  'pace',
#  'thriller',
#  'br',
#  'br',
#  'the',
#  'stori',
#  'unfold',
#  'nice',
#  'volum',
#  'even',
#  'notic',
#  'happen',
#  'br',
#  'br',
#  'fine',
#  'perform',
#  'robin',
#  'william',
#  'sexual',
#  'angl',
#  'film',
#  'seem',
#  'unnecessari',
#  'probabl',
#  'affect',
#  'much',
#  'enjoy',
#  'film',
#  'howev',
#  'core',
#  'plot',
#  'engag',
#  'movi',
#  'rush',
#  'onto',
#  'still',
#  'grip',
#  'enough',
#  'keep',
#  'wonder',
#  'direct',
#  'good',
#  'use',
#  'light',
#  'achiev',
#  'desir',
#  'affect',
#  'suspens',
#  'unexpected',
#  'good',
#  'br',
#  'br',
#  'veri',
#  'nice',
#  '1',
#  'time',
#  'watch',
#  'look',
#  'lay',
#  'back',
#  'hear',
#  'thrill',
#  'short',
#  'stori',
#  'critic',
#  'acclaim',
#  'psycholog',
#  'thriller',
#  'base',
#  'true',
#  'event',
#  'gabriel',
#  'robin',
#  'william',
#  'celebr',
#  'writer',
#  'late',
#  'night',
#  'talk',
#  'show',
#  'host',
#  'becom',
#  'captiv',
#  'harrow',
#  'stori',
#  'young',
#  'listen',
#  'adopt',
#  'mother',
#  'toni',
#  'collett',
#  'troubl',
#  'question',
#  'aris',
#  "boy'",
#  'stori',
#  'howev',
#  'gabriel',
#  'find',
#  'drawn',
#  'widen',
#  'mysteri',
#  'hide',
#  'deadli',
#  'secret',
#  'accord',
#  "film'",
#  'offici',
#  'synopsi',
#  'br',
#  'br',
#  'you',
#  'realli',
#  'stop',
#  'read',
#  'comment',
#  'watch',
#  'film',
#  'now',
#  'br',
#  'br',
#  'the',
#  'how',
#  'lose',
#  'leg',
#  'end',
#  'Ms',
#  'collett',
#  'plan',
#  'new',
#  'life',
#  'chop',
#  'off',
#  'sent',
#  'delet',
#  'scene',
#  'land',
#  'overkil',
#  'true',
#  'natur',
#  'physic',
#  'mental',
#  'ailment',
#  'obviou',
#  'time',
#  'Mr',
#  'william',
#  'return',
#  'new',
#  'york',
#  'possibl',
#  'blind',
#  'could',
#  'question',
#  'revel',
#  'could',
#  'made',
#  'certain',
#  'either',
#  'highway',
#  'video',
#  'tape',
#  'scene',
#  'film',
#  'would',
#  'benefit',
#  're',
#  'edit',
#  "director'",
#  'cut',
#  'br',
#  'br',
#  'william',
#  'bobbi',
#  'cannaval',
#  'as',
#  'jess',
#  'seem',
#  'initi',
#  'believ',
#  'coupl',
#  'scene',
#  'two',
#  'establish',
#  'relationship',
#  'might',
#  'help',
#  'set',
#  'stage',
#  'otherwis',
#  'cast',
#  'exemplari',
#  'william',
#  'offer',
#  'except',
#  'strong',
#  'character',
#  'gay',
#  'imperson',
#  'sandra',
#  'Oh',
#  'as',
#  'anna',
#  'joe',
#  'morton',
#  'as',
#  'ash',
#  'rori',
#  'culkin',
#  'pete',
#  'logand',
#  'perfect',
#  'br',
#  'br',
#  'best',
#  'all',
#  "collette'",
#  'donna',
#  'belong',
#  'creepi',
#  'hall',
#  'fame',
#  'Ms',
#  'Oh',
#  'correct',
#  'say',
#  'collett',
#  'might',
#  'be',
#  'you',
#  'know',
#  'like',
#  'guy',
#  "'psycho'",
#  'sever',
#  'year',
#  'organ',
#  'give',
#  'act',
#  'award',
#  'seem',
#  'reach',
#  'women',
#  'due',
#  'slighter',
#  'dispers',
#  'role',
#  'certainli',
#  'could',
#  'notic',
#  'collett',
#  'award',
#  'consider',
#  'good',
#  'and',
#  'director',
#  'patrick',
#  'stettner',
#  'definit',
#  'evok',
#  'hitchcock',
#  'even',
#  'make',
#  'get',
#  'sandwich',
#  'vend',
#  'machin',
#  'suspens',
#  'br',
#  'br',
#  'final',
#  'writer',
#  'stettner',
#  'armistead',
#  'maupin',
#  'terri',
#  'anderson',
#  'deserv',
#  'gratitud',
#  'flight',
#  'attend',
#  'everywher',
#  'br',
#  'br',
#  'night',
#  'listen',
#  '1',
#  '21',
#  '06',
#  'patrick',
#  'stettner',
#  'robin',
#  'william',
#  'toni',
#  'collett',
#  'sandra',
#  'Oh',
#  'rori',
#  'culkin',
#  'night',
#  'listen',
#  '2006',
#  '1',
#  '2',
#  'robin',
#  'william',
#  'toni',
#  'collett',
#  'bobbi',
#  'cannaval',
#  'rori',
#  'culkin',
#  'joe',
#  'morton',
#  'sandra',
#  'Oh',
#  'john',
#  'cullum',
#  'lisa',
#  'emeri',
#  'becki',
#  'ann',
#  'baker',
#  'dir',
#  'patrick',
#  'stettner',
#  'br',
#  'br',
#  'hitchcockian',
#  'suspens',
#  'give',
#  'william',
#  'stand',
#  'out',
#  'low',
#  'key',
#  'perform',
#  'br',
#  'br',
#  'what',
#  'celebr',
#  'fan',
#  'near',
#  'paranoia',
#  'one',
#  'associ',
#  'almost',
#  'norm',
#  'br',
#  'br',
#  'In',
#  'latest',
#  'derang',
#  'fan',
#  'scenario',
#  'base',
#  'true',
#  'event',
#  'less',
#  'william',
#  'star',
#  'talk',
#  'radio',
#  'person',
#  'name',
#  'gabriel',
#  'one',
#  'read',
#  'stori',
#  "he'",
#  'pen',
#  'airwav',
#  'accumul',
#  'interest',
#  'fan',
#  'form',
#  'young',
#  'boy',
#  'name',
#  ...]

# %% [markdown]
# ## Bag of Words (BoW)

# %% [markdown]
# ### Try unigram and bigram parameters

# %% [markdown]
# #### Unigram N = 1

# %%
# Initialize a CountVectorizer object: count_vectorizer
count_vec = CountVectorizer(analyzer='word', ngram_range=(1, 1), max_df=1.0, min_df=1, max_features=None)


# Transforms the data into a bag of words
count_train = count_vec.fit(clean_word)
bag_of_words = count_vec.transform(clean_word)

# Print count features of the count_vec
feature_name = count_vec.get_feature_names()
len(feature_name)
# Out:
# 54274

# %%
def unigram_process(data):
    from sklearn.feature_extraction.text import CountVectorizer
    vectorizer = CountVectorizer()
    vectorizer = vectorizer.fit(data)
    return vectorizer

# %%
count_train.vocabulary_
# Out:
# {'bromwell': 227454,
#  'high': 780242,
#  'cartoon': 261997,
#  'comedy': 327513,
#  'ran': 1334273,
#  'time': 1698698,
#  'programs': 1307688,
#  'school': 1442167,
#  'life': 952738,
#  'teachers': 1649647,
#  '35': 11680,
#  'years': 1892438,
#  'teaching': 1649784,
#  'profession': 1306370,
#  'lead': 935456,
#  'believe': 170945,
#  'satire': 1426919,
#  'much': 1106650,
#  'closer': 316166,
#  'reality': 1348099,
#  'scramble': 1446219,
#  'survive': 1629676,
#  'financially': 625924,
#  'insightful': 848741,
#  'students': 1604377,
#  'see': 1456729,
#  'right': 1395431,
#  'pathetic': 1223386,
#  'pomp': 1275131,
#  'pettiness': 1243409,
#  'whole': 1848358,
#  'situation': 1522211,
#  'remind': 1373033,
#  'schools': 1443142,
#  'knew': 912057,
#  'saw': 1429227,
#  'episode': 532236,
#  'student': 1604085,
#  'repeatedly': 1376285,
#  'tried': 1732379,
#  'burn': 237255,
#  'immediately': 827058,
#  'recalled': 1354733,
#  'classic': 308633,
#  'line': 966742,
#  'inspector': 849328,
#  'sack': 1418864,
#  'one': 1177769,
#  'welcome': 1834462,
#  'expect': 564136,
#  'many': 1024939,
#  'adults': 44010,
#  'age': 50228,
#  'think': 1680766,
#  'far': 590647,
#  'fetched': 607097,
#  'pity': 1253464,
#  'isn': 869596,
#  'bromwell high': 227456,
#  'high cartoon': 780320,
#  'cartoon comedy': 262058,
#  'comedy ran': 328474,
#  'ran time': 1334424,
#  'time programs': 1701191,
#  'programs school': 1307727,
#  'school life': 1442621,
#  'life teachers': 955051,
#  'teachers 35': 1649648,
#  '35 years': 11726,
#  'years teaching': 1893632,
#  'teaching profession': 1649830,
#  'profession lead': 1306400,
#  'lead believe': 935511,
#  'believe bromwell': 171067,
#  'high satire': 780696,
#  'satire much': 1427046,
#  'much closer': 1107141,
#  'closer reality': 316286,
#  'reality teachers': 1348618,
#  'teachers scramble': 1649702,
#  'scramble survive': 1446225,
#  'survive financially': 1629737,
#  'financially insightful': 625936,
#  'insightful students': 848785,
#  'students see': 1604576,
#  'see right': 1459422,
#  'right pathetic': 1396296,
#  'pathetic teachers': 1223675,
#  'teachers pomp': 1649693,
#  'pomp pettiness': 1275137,
#  'pettiness whole': 1243411,
#  'whole situation': 1848992,
#  'situation remind': 1522550,
#  'remind schools': 1373113,
#  'schools knew': 1443175,
#  'knew students': 912478,
#  'students saw': 1604572,
#  'saw episode': 1429616,
#  'episode student': 533033,
#  'student repeatedly': 1604291,
#  'repeatedly tried': 1376388,
#  'tried burn': 1732421,
#  'burn school': 237331,
#  'school immediately': 1442561,
#  'immediately recalled': 827291,
#  'recalled high': 1354744,
#  'high classic': 780337,
#  'classic line': 309079,
#  'line inspector': 967195,
#  'inspector sack': 849384,
#  'sack one': 1418893,
#  'one teachers': 1182539,
#  'teachers student': 1649709,
#  'student welcome': 1604367,
#  'welcome bromwell': 1834486,
#  'high expect': 780407,
#  'expect many': 564457,
#  'many adults': 1024986,
#  'adults age': 44018,
#  'age think': 50855,
#  'think bromwell': 1681090,
#  'high far': 780419,
#  'far fetched': 591009,
#  'fetched pity': 607151,
#  'pity isn': 1253543,
#  'homelessness': 794463,
#  'or': 1188649,
#  'houselessness': 806130,
#  'george': 688320,
#  'carlin': 259467,
#  'stated': 1578845,
#  'issue': 870070,
#  'never': 1134721,
#  'plan': 1256281,
#  'help': 771039,
#  'street': 1598819,
#  'considered': 350101,
#  'human': 810321,
#  'everything': 552006,
#  'going': 711033,
#  'work': 1871886,
#  'vote': 1806543,
#  'matter': 1037329,
#  'people': 1229084,
#  'homeless': 794379,
#  'lost': 989546,
#  'cause': 269732,
#  'worrying': 1878291,
#  'things': 1679451,
#  'racism': 1330941,
#  'war': 1814414,
#  'iraq': 865693,
#  'pressuring': 1294215,
#  'kids': 903144,
#  'succeed': 1613017,
#  'technology': 1651946,
#  'elections': 506359,
#  'inflation': 843616,
#  'they': 1676782,
#  'll': 977159,
#  'next': 1138689,
#  'end': 515538,
#  'streets': 1599335,
#  'br': 211820,
#  'but': 239667,
#  'given': 701751,
#  'bet': 178084,
#  'live': 974277,
#  'month': 1085339,
#  'without': 1861298,
#  'luxuries': 1002154,
#  'home': 793351,
#  'entertainment': 529199,
#  'sets': 1481727,
#  'bathroom': 155049,
#  'pictures': 1249101,
#  'wall': 1810427,
#  'computer': 341651,
#  'treasure': 1729390,
#  'like': 957566,
#  'goddard': 709404,
#  'bolt': 200080,
#  'lesson': 948031,
#  'mel': 1050854,
#  'brooks': 227862,
#  'who': 1847148,
#  'directs': 452494,
#  'stars': 1574912,
#  'plays': 1262762,
#  'rich': 1392323,
#  'man': 1018836,
#  'world': 1875880,
#  'deciding': 415394,
#  'make': 1012036,
#  'sissy': 1520230,
#  'rival': 1399325,
#  'jeffery': 880934,
#  'tambor': 1645465,
#  'thirty': 1684693,
#  'days': 407157,
#  'succeeds': 1613250,
#  'wants': 1813751,
#  'future': 674928,
#  'project': 1308115,
#  'making': 1016171,
#  'buildings': 234430,
#  'thrown': 1695488,
#  'bracelet': 217379,
#  'leg': 943655,
#  'monitor': 1083453,
#  'every': 549809,
#  'move': 1093991,
#  'can': 250565,
#  'step': 1582279,
#  'sidewalk': 1509609,
#  'he': 760966,
#  'nickname': 1141002,
#  'pepto': 1232168,
#  'vagrant': 1783494,
#  'written': 1887309,
#  'forehead': 650344,
#  'meets': 1050099,
#  'characters': 283424,
#  'including': 836109,
#  'woman': 1864193,
#  'name': 1120535,
#  'molly': 1079811,
#  'lesley': 946719,
#  'ann': 88592,
#  'warren': 1817058,
#  'ex': 555043,
#  'dancer': 398538,
#  'got': 719485,
#  'divorce': 463399,
#  'losing': 989160,
#  'pals': 1210584,
#  'sailor': 1422280,
#  'howard': 806709,
#  'morris': 1089331,
#  'fumes': 670759,
#  'teddy': 1652287,
#  'wilson': 1854951,
#  'already': 66871,
#  'used': 1778448,
#  're': 1341546,
#  'survivors': 1630176,
#  'reaching': 1343131,
#  'mutual': 1117298,
#  'agreements': 53420,
#  'fight': 609595,
#  'flight': 639707,
#  'kill': 904222,
#  'killed': 904875,
#  'while': 1844879,
#  'love': 993526,
#  'connection': 347975,
#  'necessary': 1128818,
#  'plot': 1266000,
#  'found': 656150,
#  'stinks': 1587891,
#  'observant': 1161582,
#  'films': 621719,
#  'prior': 1299008,
#  'shows': 1505319,
#  'tender': 1657420,
#  'side': 1508465,
#  'compared': 336110,
#  'slapstick': 1526434,
#  'blazing': 192186,
#  'saddles': 1419827,
#  'young': 1898553,
#  'frankenstein': 660219,
#  'spaceballs': 1556056,
#  'show': 1500778,
#  'something': 1543487,
#  'valuable': 1784283,
#  'day': 405645,
#  'hand': 747158,
#  'stupid': 1607209,
#  'know': 913315,
#  'money': 1082231,
#  'maybe': 1040396,
#  'give': 700610,
#  'instead': 850761,
#  'using': 1780324,
#  'monopoly': 1084031,
#  'film': 612777,
#  'inspire': 849622,
#  'others': 1195082,
#  'homelessness or': 794468,
#  'or houselessness': 1188973,
#  'houselessness george': 806131,
#  'george carlin': 688375,
#  'carlin stated': 259478,
#  'stated issue': 1578894,
#  'issue years': 870298,
#  'years never': 1893246,
#  'never plan': 1135652,
#  'plan help': 1256387,
#  'help street': 771871,
#  'street considered': 1598906,
#  'considered human': 350247,
#  'human everything': 810519,
#  'everything going': 552397,
#  'going school': 712206,
#  'school work': 1443017,
#  'work vote': 1873757,
#  'vote matter': 1806598,
#  'matter people': 1037714,
#  'people think': 1231614,
#  'think homeless': 1681820,
#  'homeless lost': 794428,
#  'lost cause': 989663,
#  'cause worrying': 270123,
#  'worrying things': 1878328,
#  'things racism': 1680370,
#  'racism war': 1331070,
#  'war iraq': 1814912,
#  'iraq pressuring': 865733,
#  'pressuring kids': 1294218,
#  'kids succeed': 903935,
#  'succeed technology': 1613119,
#  'technology elections': 1652011,
#  'elections inflation': 506364,
#  'inflation worrying': 843625,
#  'worrying they': 1878326,
#  'they ll': 1676964,
#  'll next': 977449,
#  'next end': 1138874,
#  'end streets': 517266,
#  'streets br': 1599363,
#  'br br': 212467,
#  'br but': 212558,
#  'but given': 240085,
#  'given bet': 701835,
#  'bet live': 178185,
#  'live streets': 974927,
#  'streets month': 1599461,
#  'month without': 1085446,
#  'without luxuries': 1862066,
#  'luxuries home': 1002158,
#  'home entertainment': 793610,
#  'entertainment sets': 529570,
#  'sets bathroom': 1481769,
#  'bathroom pictures': 155103,
#  'pictures wall': 1249432,
#  'wall computer': 1810482,
#  'computer everything': 341718,
#  'everything treasure': 552966,
#  'treasure see': 1729498,
#  'see like': 1458575,
#  'like homeless': 960158,
#  'homeless goddard': 794411,
#  'goddard bolt': 709406,
#  'bolt lesson': 200090,
#  'lesson br': 948054,
#  'br mel': 214911,
#  'mel brooks': 1050858,
#  'brooks who': 227991,
#  'who directs': 1847390,
#  'directs stars': 452558,
#  'stars bolt': 1575006,
#  'bolt plays': 200095,
#  'plays rich': 1263710,
#  'rich man': 1392534,
#  'man everything': 1019623,
#  'everything world': 553028,
#  'world deciding': 1876253,
#  'deciding make': 415415,
#  'make bet': 1012232,
#  'bet sissy': 178238,
#  'sissy rival': 1520271,
#  'rival jeffery': 1399402,
#  'jeffery tambor': 880945,
#  'tambor see': 1645472,
#  'see live': 1458597,
#  'streets thirty': 1599535,
#  'thirty days': 1684695,
#  'days without': 407918,
#  'luxuries bolt': 1002155,
#  'bolt succeeds': 200097,
#  'succeeds wants': 1613371,
#  'wants future': 1813989,
#  'future project': 675324,
#  'project making': 1308311,
#  'making buildings': 1016315,
#  'buildings bet': 234439,
#  'bet bolt': 178108,
#  'bolt thrown': 200098,
#  'thrown street': 1695670,
#  'street bracelet': 1598873,
#  'bracelet leg': 217384,
#  'leg monitor': 943715,
#  'monitor every': 1083459,
#  'every move': 550313,
#  'move can': 1094050,
#  'can step': 251181,
#  'step sidewalk': 1582443,
#  'sidewalk he': 1509623,
#  'he given': 761572,
#  'given nickname': 702304,
#  'nickname pepto': 1141016,
#  'pepto vagrant': 1232171,
#  'vagrant written': 1783497,
#  'written forehead': 1887598,
#  'forehead bolt': 650347,
#  'bolt meets': 200093,
#  'meets characters': 1050166,
#  'characters including': 284519,
#  'including woman': 836900,
#  'woman name': 1865092,
#  'name molly': 1121115,
#  'molly lesley': 1079834,
#  'lesley ann': 946720,
#  'ann warren': 88741,
#  'warren ex': 1817076,
#  'ex dancer': 555093,
#  'dancer got': 398581,
#  'got divorce': 719845,
#  'divorce losing': 463450,
#  'losing home': 989215,
#  'home pals': 793963,
#  'pals sailor': 1210608,
#  'sailor howard': 1422295,
#  'howard morris': 806824,
#  'morris fumes': 1089364,
#  'fumes teddy': 670762,
#  'teddy wilson': 1652299,
#  'wilson already': 1854958,
#  'already used': 67587,
#  'used streets': 1779335,
#  'streets they': 1599534,
#  'they re': 1677032,
#  're survivors': 1342519,
#  'survivors bolt': 1630185,
#  'bolt isn': 200089,
#  'isn he': 869639,
#  'he used': 762544,
#  'used reaching': 1779204,
#  'reaching mutual': 1343181,
#  'mutual agreements': 1117303,
#  'agreements like': 53422,
#  'like rich': 962164,
#  'rich fight': 1392448,
#  'fight flight': 609777,
#  'flight kill': 639765,
#  'kill killed': 904540,
#  'killed br': 904975,
#  'br while': 217172,
#  'while love': 1845082,
#  'love connection': 993973,
#  'connection molly': 348092,
#  'molly bolt': 1079818,
#  'bolt necessary': 200094,
#  'necessary plot': 1128973,
#  'plot found': 1266702,
#  'found life': 656771,
#  'life stinks': 954952,
#  'stinks one': 1587935,
#  'one mel': 1180810,
#  'brooks observant': 227950,
#  'observant films': 1161589,
#  'films prior': 623307,
#  'prior comedy': 1299036,
#  'comedy shows': 328582,
#  'shows tender': 1506428,
#  'tender side': 1657476,
#  'side compared': 1508590,
#  'compared slapstick': 336407,
#  'slapstick work': 1526564,
#  'work blazing': 1872087,
#  'blazing saddles': 192201,
#  'saddles young': 1419851,
#  'young frankenstein': 1898968,
#  'frankenstein spaceballs': 660281,
#  'spaceballs matter': 1556063,
#  'matter show': 1037789,
#  'show like': 1502046,
#  'like something': 962687,
#  'something valuable': 1545122,
#  'valuable losing': 1784325,
#  'losing next': 989256,
#  'next day': 1138832,
#  'day hand': 406182,
#  'hand making': 747592,
#  'making stupid': 1017279,
#  'stupid bet': 1607281,
#  'bet like': 178183,
#  'rich people': 1392573,
#  'people know': 1230496,
#  'know money': 914483,
#  'money maybe': 1082824,
#  'maybe give': 1040823,
#  'give homeless': 701108,
#  'homeless instead': 794419,
#  'instead using': 851924,
#  'using like': 1780628,
#  'like monopoly': 961161,
#  'monopoly money': 1084037,
#  'money br': 1082358,
#  'br or': 215301,
#  'or maybe': 1189080,
#  'maybe film': 1040771,
#  'film inspire': 616155,
#  'inspire help': 849643,
#  'help others': 771638,
#  'brilliant': 223627,
#  'over': 1200526,
#  'acting': 28414,
#  'best': 176306,
#  'dramatic': 477937,
#  'hobo': 789633,
#  'lady': 922565,
#  'ever': 548335,
#  'seen': 1465606,
#  'scenes': 1438906,
#  'clothes': 316791,
#  'warehouse': 1815765,
#  'second': 1454188,
#  'none': 1147007,
#  'corn': 363509,
#  'face': 575891,
#  'good': 714161,
#  'anything': 95799,
#  'take': 1638237,
#  'lawyers': 934699,
#  'also': 67789,
#  'superb': 1620863,
#  'accused': 25324,
#  'turncoat': 1743345,
#  'selling': 1469904,
#  'boss': 206623,
#  'dishonest': 458120,
#  'lawyer': 934515,
#  'shrugs': 1507065,
#  'indifferently': 840725,
#  'says': 1433042,
#  'three': 1691830,
#  'funny': 672701,
#  'words': 1871203,
#  'jeffrey': 880948,
#  'favorite': 597087,
#  'later': 929440,
#  'larry': 927561,
#  'sanders': 1424650,
#  'fantastic': 589716,
#  'mad': 1004522,
#  'millionaire': 1066376,
#  'crush': 388598,
#  'ghetto': 694895,
#  'character': 280263,
#  'malevolent': 1018129,
#  'usual': 1781033,
#  'hospital': 802121,
#  'scene': 1436109,
#  'invade': 862282,
#  'demolition': 423578,
#  'site': 1521561,
#  'all': 60045,
#  'classics': 309628,
#  'look': 983591,
#  'legs': 944618,
#  'two': 1747964,
#  'big': 182300,
#  'diggers': 445590,
#  'fighting': 610283,
#  'bleeds': 192466,
#  'movie': 1095281,
#  'gets': 692553,
#  'better': 178630,
#  'which': 1844191,
#  'quite': 1328466,
#  'often': 1170227,
#  'brilliant over': 224065,
#  'over acting': 1200542,
#  'acting lesley': 29338,
#  'warren best': 1817065,
#  'best dramatic': 176760,
#  'dramatic hobo': 478093,
#  'hobo lady': 789638,
#  'lady ever': 922731,
#  'ever seen': 549369,
#  'seen love': 1466721,
#  'love scenes': 995258,
#  'scenes clothes': 1439258,
#  'clothes warehouse': 317037,
#  'warehouse second': 1815796,
#  'second none': 1454572,
#  'none corn': 1147105,
#  'corn face': 363524,
#  'face classic': 576050,
#  'classic good': 308984,
#  'good anything': 714309,
#  'anything blazing': 95909,
#  'saddles take': 1419846,
#  'take lawyers': 1638921,
#  'lawyers also': 934700,
#  'also superb': 70537,
#  'superb accused': 1620870,
#  'accused turncoat': 25408,
#  'turncoat selling': 1743349,
#  'selling boss': 1469916,
#  'boss dishonest': 206703,
#  'dishonest lawyer': 458129,
#  'lawyer pepto': 934635,
#  'pepto bolt': 1232170,
#  'bolt shrugs': 200096,
#  'shrugs indifferently': 1507066,
#  'indifferently lawyer': 840726,
#  'lawyer says': 934658,
#  'says three': 1433607,
#  'three funny': 1692132,
#  'funny words': 674127,
#  'words jeffrey': 1871460,
#  'jeffrey tambor': 880981,
#  'tambor favorite': 1645469,
#  'favorite later': 597322,
#  'later larry': 930009,
#  'larry sanders': 927644,
#  'sanders show': 1424687,
#  'show fantastic': 1501565,
#  'fantastic mad': 589957,
#  'mad millionaire': 1004663,
#  'millionaire wants': 1066446,
#  'wants crush': 1813880,
#  'crush ghetto': 388630,
#  'ghetto character': 694903,
#  'character malevolent': 281706,
#  'malevolent usual': 1018152,
#  'usual hospital': 1781316,
#  'hospital scene': 802326,
#  'scene scene': 1438047,
#  'scene homeless': 1437163,
#  'homeless invade': 794420,
#  'invade demolition': 862285,
#  'demolition site': 423591,
#  'site all': 1521572,
#  'all time': 61431,
#  'time classics': 1699314,
#  'classics look': 309720,
#  'look legs': 984310,
#  'legs scene': 944722,
#  'scene two': 1438448,
#  'two big': 1748119,
#  'big diggers': 182600,
#  'diggers fighting': 445593,
#  'fighting one': 610546,
#  'one bleeds': 1178296,
#  'bleeds movie': 192470,
#  'movie gets': 1097909,
#  'gets better': 692663,
#  'better time': 180391,
#  'time see': 1701527,
#  'see which': 1460214,
#  'which quite': 1844628,
#  'quite often': 1329218,
#  'easily': 495188,
#  'underrated': 1757960,
#  'inn': 846475,
#  'cannon': 252667,
#  'sure': 1625130,
#  'flawed': 637384,
#  'realistic': 1347509,
#  'view': 1795828,
#  'unlike': 1766912,
#  'say': 1430568,
#  'citizen': 305198,
#  'kane': 895211,
#  'gave': 682221,
#  'lounge': 993160,
#  'singers': 1518368,
#  'titanic': 1705471,
#  'italians': 874410,
#  'idiots': 820934,
#  'jokes': 888005,
#  'fall': 583185,
#  'flat': 636612,
#  'still': 1585336,
#  'lovable': 993396,
#  'way': 1825833,
#  'comedies': 327212,
#  'not': 1149946,
#  'pull': 1317490,
#  'story': 1592022,
#  'traditionally': 1723872,
#  'reviled': 1390389,
#  'members': 1052032,
#  'society': 1538146,
#  'truly': 1737642,
#  'impressive': 831422,
#  'fisher': 633825,
#  'king': 909698,
#  'crap': 376124,
#  'either': 504641,
#  'complaint': 338197,
#  'cast': 264700,
#  'someone': 1542368,
#  'else': 508908,
#  'director': 450067,
#  'writer': 1885501,
#  'easily underrated': 495692,
#  'underrated film': 1758001,
#  'film inn': 616132,
#  'inn brooks': 846480,
#  'brooks cannon': 227883,
#  'cannon sure': 252725,
#  'sure flawed': 1625547,
#  'flawed give': 637425,
#  'give realistic': 701432,
#  'realistic view': 1347958,
#  'view homelessness': 1796066,
#  'homelessness unlike': 794470,
#  'unlike say': 1767194,
#  'say citizen': 1430899,
#  'citizen kane': 305226,
#  'kane gave': 895256,
#  'gave realistic': 682611,
#  'view lounge': 1796117,
#  'lounge singers': 993172,
#  'singers titanic': 1518432,
#  'titanic gave': 1705518,
#  'view italians': 1796084,
#  'italians idiots': 874422,
#  'idiots many': 820990,
#  'many jokes': 1025877,
#  'jokes fall': 888188,
#  'fall flat': 583297,
#  'flat still': 636926,
#  'still film': 1585981,
#  'film lovable': 616659,
#  'lovable way': 993511,
#  'way many': 1827426,
#  'many comedies': 1025253,
#  'comedies not': 327392,
#  'not pull': 1150599,
#  'pull story': 1317657,
#  'story traditionally': 1595218,
#  'traditionally reviled': 1723887,
#  'reviled members': 1390395,
#  'members society': 1052370,
#  'society truly': 1538621,
#  'truly impressive': 1738009,
#  'impressive fisher': 831552,
#  'fisher king': 633877,
#  'king crap': 909797,
#  'crap either': 376259,
#  'either complaint': 504807,
#  'complaint brooks': 338212,
#  'brooks cast': 227885,
#  'cast someone': 265970,
#  'someone else': 1542638,
#  'else lead': 509343,
#  'lead love': 935772,
#  'love mel': 994805,
#  'mel director': 1050863,
#  'director writer': 451958,
#  'writer much': 1885847,
#  'much lead': 1108149,
#  'typical': 1751119,
#  'less': 946783,
#  'movies': 1102266,
#  'actually': 36598,
#  'followable': 644843,
#  'leslie': 946723,
#  'made': 1004927,
#  'under': 1756990,
#  'rated': 1337829,
#  'actress': 34812,
#  'moments': 1080921,
#  'could': 366610,
#  'fleshed': 638426,
#  'bit': 186580,
#  'more': 1087631,
#  'probably': 1300308,
#  'cut': 393414,
#  'room': 1408888,
#  'so': 1536234,
#  'worth': 1879972,
#  'price': 1296957,
#  'rent': 1375122,
#  'it': 870686,
#  'overall': 1201312,
#  'job': 883940,
#  'characteristic': 283116,
#  'speaking': 1557904,
#  'directly': 449915,
#  'audience': 128288,
#  'again': 49083,
#  'actor': 31973,
#  'fume': 670756,
#  'played': 1259653,
#  'parts': 1219388,
#  'well': 1834698,
#  'typical mel': 1751412,
#  'brooks film': 227914,
#  'film much': 616987,
#  'much less': 1108162,
#  'less slapstick': 947687,
#  'slapstick movies': 1526502,
#  'movies actually': 1102336,
#  'actually plot': 37582,
#  'plot followable': 1266692,
#  'followable leslie': 644845,
#  'leslie ann': 946725,
#  'warren made': 1817089,
#  'made movie': 1006505,
#  'movie fantastic': 1097578,
#  'fantastic under': 590142,
#  'under rated': 1757060,
#  'rated actress': 1337846,
#  'actress moments': 35245,
#  'moments could': 1081089,
#  'could fleshed': 367263,
#  'fleshed bit': 638430,
#  'bit more': 187437,
#  'more scenes': 1088069,
#  'scenes could': 1439323,
#  'could probably': 367793,
#  'probably cut': 1300532,
#  'cut make': 393712,
#  'make room': 1013549,
#  'room so': 1409447,
#  'so all': 1536277,
#  'all worth': 61583,
#  'worth price': 1880291,
#  'price rent': 1297114,
#  'rent see': 1375378,
#  'see it': 1458393,
#  'it acting': 870748,
#  'acting good': 29088,
#  'good overall': 715983,
#  'overall brooks': 1201374,
#  'brooks good': 227918,
#  'good job': 715507,
#  'job without': 885096,
#  'without characteristic': 1861480,
#  'characteristic speaking': 283151,
#  'speaking directly': 1557971,
#  'directly audience': 449926,
#  'audience again': 128317,
#  'again warren': 50082,
#  'best actor': 176345,
#  'actor movie': 32693,
#  'movie fume': 1097832,
#  'fume sailor': 670758,
#  'sailor played': 1422309,
#  'played parts': 1260663,
#  'parts well': 1220047,
#  'comedic': 326997,
#  'robin': 1401643,
#  'williams': 1854189,
#  'quirky': 1328244,
#  'insane': 847523,
#  'recent': 1355357,
#  'thriller': 1692987,
#  'fame': 584460,
#  'hybrid': 816423,
#  'drama': 476975,
#  'dramatization': 478411,
#  'mixed': 1076794,
#  'new': 1136401,
#  'per': 1232178,
#  'se': 1451748,
#  'mystery': 1118571,
#  'suspense': 1630948,
#  'vehicle': 1788531,
#  'attempts': 125612,
#  'locate': 979015,
#  'sick': 1507890,
#  'boy': 209794,
#  'keeper': 898241,
#  'starring': 1574561,
#  'sandra': 1424857,
#  'oh': 1171287,
#  'rory': 1410275,
#  'culkin': 390060,
#  'pretty': 1295200,
#  'news': 1138241,
#  'report': 1377372,
#  'william': 1853996,
#  'close': 315334,
#  'achieving': 26051,
#  'goal': 708388,
#  'must': 1115712,
#  'highly': 781399,
#  'entertained': 528256,
#  'though': 1687470,
#  'fails': 580831,
#  'teach': 1649282,
#  'guide': 737259,
#  'inspect': 849312,
#  'amuse': 80335,
#  'felt': 604495,
#  'watching': 1822898,
#  'guy': 739773,
#  'performing': 1237064,
#  'actions': 31432,
#  'third': 1684227,
#  'person': 1239685,
#  'perspective': 1241854,
#  'real': 1345373,
#  'able': 17695,
#  'subscribe': 1611315,
#  'premise': 1290863,
#  'watch': 1819561,
#  'definitely': 418748,
#  'friday': 664107,
#  'saturday': 1427780,
#  'night': 1141451,
#  'fare': 591931,
#  'rates': 1338087,
#  '10': 474,
#  'from': 667356,
#  'the': 1665943,
#  'fiend': 609213,
#  'comedic robin': 327122,
#  'robin williams': 1401734,
#  'williams quirky': 1854372,
#  'quirky insane': 1328307,
#  'insane robin': 847653,
#  'williams recent': 1854375,
#  'recent thriller': 1355605,
#  'thriller fame': 1693137,
#  'fame hybrid': 584548,
#  'hybrid classic': 816432,
#  'classic drama': 308870,
#  'drama without': 477798,
#  'without over': 1862206,
#  'over dramatization': 1200665,
#  'dramatization mixed': 478421,
#  'mixed robin': 1076925,
#  'robin new': 1401697,
#  'new love': 1137119,
#  'love thriller': 995538,
#  'thriller thriller': 1693475,
#  'thriller per': 1693327,
#  'per se': 1232230,
#  'se mystery': 1451774,
#  'mystery suspense': 1118953,
#  'suspense vehicle': 1631356,
#  'vehicle williams': 1788737,
#  'williams attempts': 1854207,
#  'attempts locate': 125815,
#  'locate sick': 979048,
#  'sick boy': 1507913,
#  'boy keeper': 210214,
#  'keeper br': 898246,
#  'br also': 212032,
#  'also starring': 70449,
#  'starring sandra': 1574819,
#  'sandra oh': 1424893,
#  'oh rory': 1171680,
#  'rory culkin': 1410281,
#  'culkin suspense': 390091,
#  'suspense drama': 1631040,
#  'drama plays': 477528,
#  'plays pretty': 1263667,
#  'pretty much': 1295662,
#  'much like': 1108181,
#  'like news': 961321,
#  'news report': 1138397,
#  'report william': 1377461,
#  'william character': 1854031,
#  'character gets': 281246,
#  'gets close': 692776,
#  'close achieving': 315344,
#  'achieving goal': 26060,
#  'goal br': 708405,
#  'br must': 215081,
#  'must say': 1116541,
#  'say highly': 1431359,
#  'highly entertained': 781497,
#  'entertained though': 528409,
#  'though movie': 1688561,
#  'movie fails': 1097548,
#  'fails teach': 581120,
#  'teach guide': 1649324,
#  'guide inspect': 737304,
#  'inspect amuse': 849313,
#  'amuse felt': 80349,
#  'felt like': 604838,
#  'like watching': 963529,
#  'watching guy': 1823535,
#  'guy williams': 741240,
#  'williams actually': 1854193,
#  'actually performing': 37555,
#  'performing actions': 1237066,
#  'actions third': 31641,
#  'third person': 1684411,
#  'person perspective': 1240265,
#  'perspective words': 1242064,
#  'words felt': 1871390,
#  'felt real': 604974,
#  'real able': 1345379,
#  'able subscribe': 18120,
#  'subscribe premise': 1611322,
#  'premise story': 1291230,
#  'story br': 1592385,
#  'br all': 212019,
#  'all all': 60086,
#  ...}

# %% [markdown]
# ## N = 2

# %%
# Initialize a CountVectorizer object: count_vectorizer
count_vec = CountVectorizer(analyzer='word', ngram_range=(1, 2), max_df=1.0, min_df=1, max_features=None)


# Transforms the data into a bag of words
count_train = count_vec.fit(clean_word)
bag_of_words = count_vec.transform(clean_word)

# Print count features of the count_vec
len(count_vec.get_feature_names())
# Out:
# 54532

# %%
def bigram_process(data):
    from sklearn.feature_extraction.text import CountVectorizer
    vectorizer = CountVectorizer(ngram_range=(1,2))
    vectorizer = vectorizer.fit(data)
    return vectorizer

# %% [markdown]
# As oberseved, when N increase, the number of feature increase, too

# %% [markdown]
# ##  Term Frequency - Inverse Document Frequency (TF-IDF)

# %%
tf = TfidfVectorizer(smooth_idf=False, sublinear_tf=False, norm=None, analyzer='word')
txt_fitted = tf.fit(text)
txt_transformed = txt_fitted.transform(text)
vocabulary = [tf.vocabulary_]
vocabulary
# Out:
# [{'bromwell': 9227,
#   'high': 30773,
#   'cartoon': 10814,
#   'comedy': 13446,
#   'ran': 53198,
#   'time': 66678,
#   'programs': 51721,
#   'school': 57799,
#   'life': 38515,
#   'teachers': 65496,
#   '35': 641,
#   'years': 73904,
#   'teaching': 65498,
#   'profession': 51662,
#   'lead': 37913,
#   'believe': 6699,
#   'satire': 57354,
#   'much': 44060,
#   'closer': 12889,
#   'reality': 53599,
#   'scramble': 57987,
#   'survive': 64444,
#   'financially': 24527,
#   'insightful': 33685,
#   'students': 63532,
#   'see': 58352,
#   'right': 55606,
#   'pathetic': 48493,
#   'pomp': 50538,
#   'pettiness': 49325,
#   'whole': 72654,
#   'situation': 60259,
#   'remind': 54561,
#   'schools': 57820,
#   'knew': 36706,
#   'saw': 57466,
#   'episode': 22132,
#   'student': 63531,
#   'repeatedly': 54722,
#   'tried': 67896,
#   'burn': 9739,
#   'immediately': 32595,
#   'recalled': 53736,
#   'classic': 12638,
#   'line': 38703,
#   'inspector': 33726,
#   'sack': 56795,
#   'one': 46733,
#   'welcome': 72286,
#   'expect': 23035,
#   'many': 40650,
#   'adults': 1912,
#   'age': 2147,
#   'think': 66278,
#   'far': 23696,
#   'fetched': 24237,
#   'pity': 49948,
#   'isn': 34507,
#   'homelessness': 31281,
#   'or': 46943,
#   'houselessness': 31704,
#   'george': 27112,
#   'carlin': 10667,
#   'stated': 62689,
#   'issue': 34535,
#   'never': 45231,
#   'plan': 50022,
#   'help': 30419,
#   'street': 63335,
#   'considered': 14256,
#   'human': 31893,
#   'everything': 22681,
#   'going': 27854,
#   'work': 73359,
#   'vote': 71508,
#   'matter': 41242,
#   'people': 48942,
#   'homeless': 31280,
#   'lost': 39318,
#   'cause': 11105,
#   'worrying': 73424,
#   'things': 66276,
#   'racism': 52904,
#   'war': 71840,
#   'iraq': 34341,
#   'pressuring': 51332,
#   'kids': 36370,
#   'succeed': 63845,
#   'technology': 65572,
#   'elections': 21148,
#   'inflation': 33402,
#   'they': 66226,
#   'll': 38933,
#   'next': 45309,
#   'end': 21683,
#   'streets': 63344,
#   'br': 8701,
#   'but': 9854,
#   'given': 27511,
#   'bet': 7042,
#   'live': 38888,
#   'month': 43522,
#   'without': 73107,
#   'luxuries': 39738,
#   'home': 31270,
#   'entertainment': 21972,
#   'sets': 58803,
#   'bathroom': 6202,
#   'pictures': 49660,
#   'wall': 71746,
#   'computer': 13824,
#   'treasure': 67738,
#   'like': 38587,
#   'goddard': 27800,
#   'bolt': 8215,
#   'lesson': 38293,
#   'mel': 41860,
#   'brooks': 9258,
#   'who': 72647,
#   'directs': 18513,
#   'stars': 62657,
#   'plays': 50130,
#   'rich': 55490,
#   'man': 40412,
#   'world': 73394,
#   'deciding': 16865,
#   'make': 40244,
#   'sissy': 60227,
#   'rival': 55775,
#   'jeffery': 34996,
#   'tambor': 65180,
#   'thirty': 66310,
#   'days': 16641,
#   'succeeds': 63848,
#   'wants': 71838,
#   'future': 26351,
#   'project': 51741,
#   'making': 40264,
#   'buildings': 9534,
#   'thrown': 66467,
#   'bracelet': 8706,
#   'leg': 38054,
#   'monitor': 43422,
#   'every': 22671,
#   'move': 43953,
#   'can': 10323,
#   'step': 62858,
#   'sidewalk': 59886,
#   'he': 30081,
#   'nickname': 45381,
#   'pepto': 48969,
#   'vagrant': 70393,
#   'written': 73583,
#   'forehead': 25405,
#   'meets': 41794,
#   'characters': 11600,
#   'including': 33004,
#   'woman': 73216,
#   'name': 44647,
#   'molly': 43331,
#   'lesley': 38280,
#   'ann': 3445,
#   'warren': 71918,
#   'ex': 22761,
#   'dancer': 16356,
#   'got': 28106,
#   'divorce': 19202,
#   'losing': 39315,
#   'pals': 47959,
#   'sailor': 56914,
#   'howard': 31729,
#   'morris': 43737,
#   'fumes': 26227,
#   'teddy': 65576,
#   'wilson': 72880,
#   'already': 2803,
#   'used': 70254,
#   're': 53522,
#   'survivors': 64451,
#   'reaching': 53534,
#   'mutual': 44436,
#   'agreements': 2236,
#   'fight': 24382,
#   'flight': 24958,
#   'kill': 36400,
#   'killed': 36405,
#   'while': 72527,
#   'love': 39397,
#   'connection': 14156,
#   'necessary': 44969,
#   'plot': 50220,
#   'found': 25618,
#   'stinks': 63035,
#   'observant': 46299,
#   'films': 24486,
#   'prior': 51502,
#   'shows': 59667,
#   'tender': 65775,
#   'side': 59855,
#   'compared': 13643,
#   'slapstick': 60507,
#   'blazing': 7682,
#   'saddles': 56832,
#   'young': 74080,
#   'frankenstein': 25768,
#   'spaceballs': 61675,
#   'show': 59639,
#   'something': 61399,
#   'valuable': 70477,
#   'day': 16628,
#   'hand': 29520,
#   'stupid': 63595,
#   'know': 36756,
#   'money': 43391,
#   'maybe': 41337,
#   'give': 27508,
#   'instead': 33756,
#   'using': 70273,
#   'monopoly': 43453,
#   'film': 24441,
#   'inspire': 33732,
#   'others': 47211,
#   'brilliant': 9090,
#   'over': 47413,
#   'acting': 1615,
#   'best': 7023,
#   'dramatic': 19901,
#   'hobo': 31099,
#   'lady': 37303,
#   'ever': 22648,
#   'seen': 58380,
#   'scenes': 57651,
#   'clothes': 12905,
#   'warehouse': 71861,
#   'second': 58280,
#   'none': 45711,
#   'corn': 14787,
#   'face': 23395,
#   'good': 27959,
#   'anything': 3700,
#   'take': 65081,
#   'lawyers': 37858,
#   'also': 2810,
#   'superb': 64158,
#   'accused': 1497,
#   'turncoat': 68368,
#   'selling': 58487,
#   'boss': 8540,
#   'dishonest': 18784,
#   'lawyer': 37855,
#   'shrugs': 59729,
#   'indifferently': 33191,
#   'says': 57501,
#   'three': 66410,
#   'funny': 26284,
#   'words': 73351,
#   'jeffrey': 34997,
#   'favorite': 23912,
#   'later': 37699,
#   'larry': 37626,
#   'sanders': 57136,
#   'fantastic': 23677,
#   'mad': 39967,
#   'millionaire': 42612,
#   'crush': 15771,
#   'ghetto': 27235,
#   'character': 11580,
#   'malevolent': 40317,
#   'usual': 70283,
#   'hospital': 31617,
#   'scene': 57646,
#   'invade': 34194,
#   'demolition': 17388,
#   'site': 60247,
#   'all': 2652,
#   'classics': 12644,
#   'look': 39199,
#   'legs': 38102,
#   'two': 68520,
#   'big': 7238,
#   'diggers': 18305,
#   'fighting': 24388,
#   'bleeds': 7708,
#   'movie': 43966,
#   'gets': 27204,
#   'better': 7073,
#   'which': 72516,
#   'quite': 52815,
#   'often': 46544,
#   'easily': 20686,
#   'underrated': 69127,
#   'inn': 33573,
#   'cannon': 10405,
#   'sure': 64350,
#   'flawed': 24883,
#   'realistic': 53594,
#   'view': 71080,
#   'unlike': 69587,
#   'say': 57488,
#   'citizen': 12521,
#   'kane': 35820,
#   'gave': 26851,
#   'lounge': 39370,
#   'singers': 60140,
#   'titanic': 66815,
#   'italians': 34553,
#   'idiots': 32355,
#   'jokes': 35337,
#   'fall': 23540,
#   'flat': 24834,
#   'still': 62989,
#   'lovable': 39394,
#   'way': 72081,
#   'comedies': 13443,
#   'not': 45858,
#   'pull': 52266,
#   'story': 63186,
#   'traditionally': 67433,
#   'reviled': 55311,
#   'members': 41939,
#   'society': 61195,
#   'truly': 68128,
#   'impressive': 32815,
#   'fisher': 24669,
#   'king': 36479,
#   'crap': 15288,
#   'either': 21075,
#   'complaint': 13711,
#   'cast': 10919,
#   'someone': 61385,
#   'else': 21317,
#   'director': 18507,
#   'writer': 73572,
#   'typical': 68562,
#   'less': 38286,
#   'movies': 43983,
#   'actually': 1662,
#   'followable': 25258,
#   'leslie': 38281,
#   'made': 39993,
#   'under': 69037,
#   'rated': 53368,
#   'actress': 1652,
#   'moments': 43350,
#   'could': 15003,
#   'fleshed': 24928,
#   'bit': 7463,
#   'more': 43657,
#   'probably': 51561,
#   'cut': 16067,
#   'room': 56168,
#   'so': 61141,
#   'worth': 73445,
#   'price': 51419,
#   'rent': 54671,
#   'it': 34546,
#   'overall': 47424,
#   'job': 35240,
#   'characteristic': 11590,
#   'speaking': 61801,
#   'directly': 18505,
#   'audience': 4936,
#   'again': 2140,
#   'actor': 1647,
#   'fume': 26226,
#   'played': 50108,
#   'parts': 48384,
#   'well': 72299,
#   'comedic': 13439,
#   'robin': 55903,
#   'williams': 72851,
#   'quirky': 52810,
#   'insane': 33644,
#   'recent': 53769,
#   'thriller': 66426,
#   'fame': 23587,
#   'hybrid': 32119,
#   'drama': 19897,
#   'dramatization': 19913,
#   'mixed': 43098,
#   'new': 45242,
#   'per': 48973,
#   'se': 58170,
#   'mystery': 44500,
#   'suspense': 64481,
#   'vehicle': 70707,
#   'attempts': 4856,
#   'locate': 39006,
#   'sick': 59830,
#   'boy': 8678,
#   'keeper': 36096,
#   'starring': 62655,
#   'sandra': 57148,
#   'oh': 46561,
#   'rory': 56206,
#   'culkin': 15888,
#   'pretty': 51381,
#   'news': 45277,
#   'report': 54790,
#   'william': 72850,
#   'close': 12885,
#   'achieving': 1530,
#   'goal': 27759,
#   'must': 44378,
#   'highly': 30794,
#   'entertained': 21965,
#   'though': 66371,
#   'fails': 23475,
#   'teach': 65494,
#   'guide': 28905,
#   'inspect': 33722,
#   'amuse': 3141,
#   'felt': 24108,
#   'watching': 72001,
#   'guy': 29116,
#   'performing': 49042,
#   'actions': 1631,
#   'third': 66297,
#   'person': 49179,
#   'perspective': 49208,
#   'real': 53582,
#   'able': 1223,
#   'subscribe': 63747,
#   'premise': 51218,
#   'watch': 71988,
#   'definitely': 17111,
#   'friday': 25978,
#   'saturday': 57393,
#   'night': 45446,
#   'fare': 23711,
#   'rates': 53371,
#   '10': 39,
#   'from': 26079,
#   'the': 66091,
#   'fiend': 24351,
#   'yes': 73953,
#   'art': 4353,
#   'successfully': 63855,
#   'slow': 60733,
#   'paced': 47744,
#   'unfolds': 69355,
#   'nice': 45348,
#   'volumes': 71468,
#   'even': 22629,
#   'notice': 45886,
#   'happening': 29646,
#   'fine': 24541,
#   'performance': 49036,
#   'sexuality': 58895,
#   'angles': 3357,
#   'seem': 58371,
#   'unnecessary': 69664,
#   'affect': 2016,
#   'enjoy': 21835,
#   'however': 31738,
#   'core': 14760,
#   'engaging': 21775,
#   'rush': 56624,
#   'onto': 46776,
#   'grips': 28626,
#   'enough': 21879,
#   'keep': 36094,
#   'wondering': 73242,
#   'direction': 18498,
#   'use': 70253,
#   'lights': 38577,
#   'achieve': 1522,
#   'desired': 17761,
#   'affects': 2029,
#   'unexpectedness': 69298,
#   'very': 70908,
#   'looking': 39207,
#   'lay': 37864,
#   'back': 5415,
#   'hear': 30150,
#   'thrilling': 66428,
#   'short': 59572,
#   'critically': 15562,
#   'acclaimed': 1428,
#   'psychological': 52139,
#   'based': 6096,
#   'true': 68111,
#   'events': 22641,
#   'gabriel': 26404,
#   'celebrated': 11223,
#   'late': 37690,
#   'talk': 65129,
#   'host': 31625,
#   'becomes': 6464,
#   'captivated': 10537,
#   'harrowing': 29834,
#   'listener': 38821,
#   'adoptive': 1862,
#   'mother': 43832,
#   'toni': 67054,
#   'collette': 13296,
#   'troubling': 68062,
#   'questions': 52733,
#   'arise': 4171,
#   'finds': 24539,
#   'drawn': 19953,
#   'widening': 72739,
#   'hides': 30756,
#   'deadly': 16694,
#   'secret': 58289,
#   'according': 1460,
#   'official': 46518,
#   'synopsis': 64894,
#   'you': 74070,
#   'really': 53612,
#   'stop': 63143,
#   'reading': 53560,
#   'comments': 13533,
#   'now': 45961,
#   'how': 31728,
#   'lose': 39310,
#   'ending': 21708,
#   'ms': 44031,
#   'planning': 50042,
#   'chopped': 12166,
#   'off': 46487,
#   'sent': 58614,
#   'deleted': 17243,
#   'land': 37472,
#   'overkill': 47525,
#   'nature': 44834,
#   'physical': 49579,
#   'mental': 42033,
#   'ailments': 2308,
#   'obvious': 46352,
#   'mr': 44024,
#   'returns': 55231,
#   'york': 74049,
#   'possibly': 50802,
#   'blindness': 7759,
#   'question': 52726,
#   'revelation': 55260,
#   'certain': 11343,
#   'highway': 30809,
#   'video': 71030,
#   'tape': 65279,
#   'would': 73457,
#   'benefit': 6817,
#   'editing': 20847,
#   'bobby': 8044,
#   'cannavale': 10388,
#   'as': 4445,
#   'jess': 35094,
#   'initially': 33534,
#   'believable': 6697,
#   'couple': 15083,
#   'establishing': 22445,
#   'relationship': 54414,
#   'might': 42475,
#   'helped': 30420,
#   'set': 58792,
#   'stage': 62456,
#   'otherwise': 47212,
#   'exemplary': 22929,
#   'offers': 46510,
#   'exceptionally': 22835,
#   'strong': 63461,
#   'characterization': 11593,
#   'gay': 26867,
#   'impersonation': 32714,
#   'anna': 3446,
#   'joe': 35270,
#   'morton': 43777,
#   'ashe': 4480,
#   'pete': 49286,
#   'logand': 39069,
#   'perfect': 49016,
#   'donna': 19528,
#   'belongs': 6753,
#   'creepy': 15436,
#   'hall': 29389,
#   'correct': 14850,
#   'saying': 57495,
#   'be': 6314,
#   'psycho': 52123,
#   'several': 58838,
#   'organizations': 47040,
#   'giving': 27516,
#   'awards': 5228,
#   'seemed': 58374,
#   'reach': 53530,
#   'women': 73230,
#   'due': 20265,
#   'slighter': 60631,
#   'dispersion': 18929,
#   'roles': 56055,
#   'certainly': 11344,
#   'noticed': 45889,
#   'award': 5224,
#   'consideration': 14254,
#   'and': 3241,
#   'patrick': 48533,
#   'stettner': 62927,
#   'evokes': 22723,
#   'hitchcock': 30996,
#   'makes': 40254,
#   'getting': 27209,
#   'sandwich': 57157,
#   'vending': 70746,
#   'machine': 39902,
#   'suspenseful': 64482,
#   'finally': 24521,
#   'writers': 73573,
#   'armistead': 4235,
#   'maupin': 41286,
#   'terry': 65937,
#   'anderson': 3254,
#   'deserve': 17736,
#   'gratitude': 28377,
#   'attendants': 4861,
#   'everywhere': 22688,
#   '21': 499,
#   '06': 27,
#   '2006': 447,
#   'john': 35300,
#   'cullum': 15895,
#   'lisa': 38804,
#   'emery': 21467,
#   'becky': 6459,
#   'baker': 5598,
#   'dir': 18491,
#   'hitchcockian': 30997,
#   'suspenser': 64485,
#   'gives': 27514,
#   'stand': 62557,
#   'out': 47250,
#   'low': 39437,
#   'key': 36249,
#   'what': 72446,
#   'celebrities': 11231,
#   'fans': 23658,
#   'near': 44937,
#   'paranoia': 48178,
#   'associates': 4640,
#   'almost': 2757,
#   'norm': 45791,
#   'in': 32870,
#   'latest': 37702,
#   'derange': 17632,
#   'fan': 23610,
#   'scenario': 57641,
#   'radio': 52954,
#   'personality': 49187,
#   'named': 44648,
#   'reads': 53567,
#   'stories': 63169,
#   'penned': 48902,
#   'airwaves': 2380,
#   'accumulated': 1483,
#   'interesting': 33944,
#   'form': 25490,
#   'submitted': 63730,
#   'manuscript': 40645,
#   'travails': 67692,
#   'troubled': 68055,
#   'youth': 74105,
#   'editor': 20850,
#   'read': 53550,
#   'himself': 30885,
#   'no': 45613,
#   'naturally': 44831,
#   'disturbed': 19128,
#   'ultimately': 68710,
#   'intrigued': 34148,
#   'nightmarish': 45463,
#   'existence': 22983,
#   'abducted': 1174,
#   'sexually': 58897,
#   'abused': 1351,
#   'rescued': 54910,
#   'nurse': 46093,
#   'excellent': 22823,
#   'adopted': 1856,
#   'correspondence': 14871,
#   'reveals': 55257,
#   'dying': 20567,
#   'aids': 2294,
#   'meet': 41791,
#   'suddenly': 63905,
#   'doubt': 19732,
#   'devious': 18016,
#   'ulterior': 68708,
#   'motives': 43863,
#   'seed': 58354,
#   'planted': 50049,
#   'estranged': 22484,
#   'lover': 39422,
#   'whose': 72698,
#   'sudden': 63904,
#   'departure': 17545,
#   'city': 12530,
#   'apartment': 3735,
#   'emotional': 21525,
#   'tailspin': 65050,
#   'grown': 28758,
#   'tempest': 65727,
#   'teacup': 65501,
#   'decides': 16864,
#   'investigating': 34242,
#   'backgrounds': 5434,
#   'discovering': 18693,
#   'truths': 68160,
#   'anticipate': 3594,
#   'co': 12998,
#   'wrote': 73596,
#   'screenplay': 58041,
#   'former': 25511,
#   'novice': 45954,
#   'hoax': 31076,
#   'run': 56587,
#   'full': 26206,
#   'tilt': 66661,
#   'old': 46633,
#   'fashioned': 23809,
#   'pot': 50848,
#   'boiler': 8152,
#   'does': 19350,
#   'helps': 30431,
#   'conflicted': 14052,
#   'hearted': 30177,
#   'genuinely': 27080,
#   'number': 46051,
#   'fact': 23426,
#   'thing': 66270,
#   'escaped': 22337,
#   'unsettling': 69884,
#   'dreadful': 19961,
#   'trait': 67480,
#   'leave': 37980,
#   'unmentioned': 69636,
#   'underlines': 69095,
#   'desperation': 17796,
#   'rattle': 53403,
#   'runs': 56601,
#   'gas': 26770,
#   'eventually': 22644,
#   'repetitive': 54748,
#   'predictable': 51121,
#   'despite': 17809,
#   'finely': 24543,
#   'directed': 18494,
#   'piece': 49677,
#   'hoodwink': 31412,
#   'pays': 48655,
#   'listen': 38818,
#   'inner': 33584,
#   'voice': 71419,
#   'careful': 10613,
#   'hope': 31465,
#   'for': 25354,
#   'god': 27786,
#   'bless': 7729,
#   'him': 30873,
#   'constantly': 14308,
#   'shooting': 59545,
#   'foot': 25318,
#   'lately': 37695,
#   'dumb': 20328,
#   'done': 19514,
#   'decade': 16810,
#   'with': 73085,
#   'perhaps': 49049,
#   'exception': 22833,
#   'death': 16737,
#   'smoochy': 60905,
#   'bombed': 8241,
#   'came': 10237,
#   'cult': 15907,
#   'dramas': 19900,
#   'especially': 22394,
#   'insomnia': 33717,
#   'hour': 31685,
#   'photo': 49533,
#   'mediocre': 41751,
#   'reviews': 55309,
#   'quick': 52748,
#   'dvd': 20512,
#   'release': 54436,
#   'among': 3079,
#   'period': 49060,
#   'this': 66314,
#   'chilling': 12031,
#   'include': 33001,
#   'serial': 58732,
#   'killer': 36406,
#   'anyone': 3697,
#   'physically': 49583,
#   'dangerous': 16388,
#   'concept': 13874,
#   'actual': 1656,
#   'case': 10858,
#   'fraud': 25808,
#   'yet': 73962,
#   'officially': 46520,
#   'confirmed': 14041,
#   'autobiography': 5075,
#   'child': 12005,
#   'anthony': 3573,
#   'godby': 27793,
#   'johnson': 35311,
#   'suffered': 63928,
#   'horrific': 31545,
#   'abuse': 1350,
#   'contracted': 14485,
#   'result': 55115,
#   'moved': 43955,
#   'reports': 54799,
#   'online': 46755,
#   'may': 41331,
#   'exist': 22979,
#   'confused': 14083,
#   'feelings': 24035,
#   'brilliantly': 9092,
#   'portrayed': 50739,
#   'resurfaced': 55126,
#   'mind': 42661,
#   'sociopathic': 61202,
#   'caretaker': 10628,
#   'role': 56054,
#   'cry': 15788,
#   'little': 38876,
#   'miss': 42997,
#   'sunshine': 64143,
#   'times': 66696,
#   'looked': 39202,
#   'camera': 10246,
#   'thought': 66373,
#   'staring': 62633,
#   'me': 41613,
#   'takes': 65096,
#   'play': 50103,
#   'sort': 61546,
#   'understated': 69147,
#   'reviewed': 55304,
#   'actresses': 1653,
#   'generation': 27001,
#   'nominated': 45687,
#   'academy': 1377,
#   '2008': 449,
#   'incredible': 33090,
#   'least': 37967,
#   'scary': 57609,
#   'too': 67074,
#   'dark': 16473,
#   'recommend': 53852,
#   'prepared': 51241,
#   'unsettled': 69882,
#   'leaves': 37985,
#   'strange': 63260,
#   'feeling': 24034,
#   'first': 24655,
#   'maupins': 41287,
#   'taken': 65087,
#   'displayed': 18937,
#   'cares': 10624,
#   'loves': 39424,
#   'said': 56905,
#   'version': 70886,
#   'expected': 23041,
#   'past': 48441,
#   'gloss': 27693,
#   'hollywood': 31226,
#   'succeeded': 63846,
#   'amount': 3092,
#   'restraint': 55098,
#   'captures': 10548,
#   'fragile': 25685,
#   'essence': 22433,
#   'lets': 38315,
#   'us': 70241,
#   'struggle': 63490,
#   'issues': 34537,
#   'trust': 68146,
#   'personnel': 49206,
#   'around': 4278,
#   'introduced': 34158,
#   'players': 50110,
#   'reminded': 54562,
#   'nothing': 45882,
#   'seems': 58378,
#   'smallest': 60802,
#   'event': 22636,
#   'change': 11515,
#   'lives': 38904,
#   'irrevocably': 34429,
#   'request': 54882,
#   'review': 55303,
#   'book': 8354,
#   'turns': 68379,
#   'changing': 11523,
#   'find': 24533,
#   'strength': 63355,
#   'within': 73104,
#   'carry': 10791,
#   'forward': 25584,
#   'bad': 5481,
#   'avoid': 5188,
#   'average': 5155,
#   'american': 3006,
#   'serious': 58740,
#   'before': 6558,
#   'please': 50157,
#   'chance': 11488,
#   'touches': 67283,
#   'darkness': 16491,
#   'go': 27754,
#   'stepped': 62882,
#   'another': 3521,
#   'quality': 52625,
#   'forget': 25460,
#   'steals': 62769,
#   '1940': 336,
#   'leading': 37922,
#   'looks': 39212,
#   'screen': 58032,
#   'presence': 51284,
#   'hacks': 29237,
#   'opinion': 46870,
#   'liked': 38591,
#   'action': 1620,
#   'tense': 65818,
#   'opening': 46835,
#   'semi': 58515,
#   'truck': 68093,
#   'some': 61378,
#   'transitional': 67575,
#   'filmed': 24457,
#   'ways': 72094,
#   'lapse': 37579,
#   'photography': 49547,
#   'unusual': 70021,
#   'colors': 13363,
#   'evil': 22704,
#   'illnesses': 32473,
#   'born': 8500,
#   'modern': 43211,
#   'constant': 14306,
#   'vigilance': 71096,
#   'accrued': 1479,
#   'information': 33431,
#   'realm': 53613,
#   'pyschosis': 52558,
#   'kept': 36192,
#   'psychologists': 52143,
#   'counselors': 15030,
#   'psychiatrists': 52115,
#   'busy': 9850,
#   'last': 37675,
#   'decades': 16814,
#   'occasionally': 46366,
#   'phenomenon': 49413,
#   'discover': 18689,
#   'knowledge': 36760,
#   'remedy': 54548,
#   'entitled': 22002,
#   'listner': 38833,
#   'tells': 65704,
#   'popular': 50642,
#   'called': 10177,
#   'noon': 45755,
#   'spends': 61925,
#   'evenings': 22634,
#   'enthralling': 21977,
#   'audiences': 4939,
#   'vivid': 71367,
#   'lifestyles': 38537,
#   'authentic': 5043,
#   'veneer': 70749,
#   'causes': 11107,
#   'admit': 1826,
#   'longer': 39159,
#   'abandoned': 1142,
#   'friend': 25996,
#   'seeks': 58368,
#   'shelter': 59267,
#   'deepening': 16996,
#   'despair': 17781,
#   'isolation': 34515,
#   'here': 30541,
#   'mysterious': 44497,
#   'asks': 4527,
#   'needs': 45015,
#   'feel': 24032,
#   'useful': 70255,
#   'reaches': 53533,
#   'desperate': 17793,
#   '14': 136,
#   'year': 73893,
#   'peter': 49287,
#   'depicts': 17565,
#   'early': 20641,
#   'sexual': 58890,
#   'hands': 29564,
#   'brutal': 9364,
#   'parents': 48237,
#   ...}]

# %%
idf = tf.idf_
print(dict(zip(txt_fitted.get_feature_names(), idf)))
# Out:
# {'00': 6.7321819491778987, '000': 5.7330035574979759, '0000000000001': 11.126631103850338, '00001': 10.433483923290392, '00015': 11.126631103850338, '000s': 11.126631103850338, '001': 10.028018815182229, '003830': 11.126631103850338, '006': 11.126631103850338, '007': 8.4185809027481291, '0079': 11.126631103850338, '0080': 10.028018815182229, '0083': 10.433483923290392, '0093638': 11.126631103850338, '00am': 9.740336742730447, '00pm': 9.740336742730447, '00s': 9.3348716346222833, '01': 7.9485772735023925, '01pm': 11.126631103850338, '02': 8.3540423816105562, '020410': 11.126631103850338, '029': 11.126631103850338, '03': 9.5171931914162382, '04': 9.5171931914162382, '041': 11.126631103850338, '05': 8.5616817463887998, '050': 11.126631103850338, '06': 8.5616817463887998, '06th': 11.126631103850338, '07': 8.6417244540623379, '08': 8.7287358310519672, '087': 11.126631103850338, '089': 11.126631103850338, '08th': 11.126631103850338, '09': 9.0471895621705016, '0f': 11.126631103850338, '0ne': 11.126631103850338, '0r': 11.126631103850338, '0s': 11.126631103850338, '10': 2.9989312510325661, '100': 5.1326696765437685, '1000': 7.388961485566969, '1000000': 11.126631103850338, '10000000000000': 11.126631103850338, '1000lb': 11.126631103850338, '1000s': 10.433483923290392, '1001': 10.433483923290392, '100b': 11.126631103850338, '100k': 11.126631103850338, '100m': 11.126631103850338, '100min': 10.433483923290392, '100mph': 11.126631103850338, '100s': 10.433483923290392, '100th': 9.3348716346222833, '100x': 10.433483923290392, '100yards': 11.126631103850338, '101': 7.2554300929424471, '101st': 10.433483923290392, '102': 8.487573774235079, '102nd': 11.126631103850338, '103': 9.5171931914162382, '104': 9.1807209547950244, '1040': 11.126631103850338, '1040a': 11.126631103850338, '1040s': 11.126631103850338, '105': 8.8240460108562928, '1050': 11.126631103850338, '105lbs': 11.126631103850338, '106': 9.740336742730447, '106min': 11.126631103850338, '107': 9.3348716346222833, '108': 9.3348716346222833, '109': 9.740336742730447, '10am': 11.126631103850338, '10lines': 11.126631103850338, '10mil': 11.126631103850338, '10min': 11.126631103850338, '10minutes': 11.126631103850338, '10p': 11.126631103850338, '10pm': 10.028018815182229, '10s': 9.3348716346222833, '10star': 11.126631103850338, '10th': 8.4185809027481291, '10x': 10.028018815182229, '10yr': 11.126631103850338, '11': 5.5026135976629993, '110': 8.4185809027481291, '1100': 9.740336742730447, '11001001': 11.126631103850338, '1100ad': 11.126631103850338, '111': 10.433483923290392, '112': 9.3348716346222833, '1138': 10.433483923290392, '114': 10.433483923290392, '1146': 11.126631103850338, '115': 10.028018815182229, '116': 9.5171931914162382, '117': 9.5171931914162382, '11f': 11.126631103850338, '11m': 11.126631103850338, '11th': 7.9911368879211881, '12': 5.4195208391014624, '120': 8.2934177597941208, '1200': 9.740336742730447, '1200f': 11.126631103850338, '1201': 11.126631103850338, '1202': 11.126631103850338, '123': 10.433483923290392, '12383499143743701': 11.126631103850338, '125': 10.028018815182229, '125m': 11.126631103850338, '127': 11.126631103850338, '128': 10.028018815182229, '12a': 10.028018815182229, '12hr': 11.126631103850338, '12m': 10.433483923290392, '12mm': 11.126631103850338, '12s': 11.126631103850338, '12th': 8.5616817463887998, '13': 5.6670455897061789, '130': 10.433483923290392, '1300': 11.126631103850338, '1300s': 10.433483923290392, '131': 10.028018815182229, '1318': 11.126631103850338, '132': 10.433483923290392, '134': 10.028018815182229, '135': 9.3348716346222833, '135m': 11.126631103850338, '136': 10.433483923290392, '137': 11.126631103850338, '138': 9.740336742730447, '139': 11.126631103850338, '13k': 11.126631103850338, '13s': 10.433483923290392, '13th': 6.7446044691764566, '14': 5.8639409149454522, '140': 8.5616817463887998, '1408': 10.028018815182229, '140hp': 11.126631103850338, '1415': 11.126631103850338, '142': 11.126631103850338, '145': 10.433483923290392, '1454': 11 ...

# %%
def tfidf_process(data):
    from sklearn.feature_extraction.text import TfidfTransformer 
    transformer = TfidfTransformer()
    transformer = transformer.fit(data)
    return transformer

# %% [markdown]
# ## Get the feature with lowest and highest TFIDF

# %%
new1 = tf.transform(clean_word)

# find maximum value for each of the features over all of dataset:
max_val = new1.max(axis=0).toarray()

#sort weights from smallest to biggest and extract their indices 
sort_by_tfidf = max_val.argsort()

print("Features with lowest tfidf:\n{}".format(
      feature_name[sort_by_tfidf[0][0]]))

#print("\nFeatures with highest tfidf: \n{}".format(
      #feature_name[sort_by_tfidf[0][902]]))
# Out:
# Features with lowest tfidf:
# powell

# %%
sort_by_tfidf[0]
# Out:
# array([37311, 26635, 26636, ..., 63778, 51148, 74623], dtype=int64)

# %% [markdown]
#  ## Feature hashing

# %%
h = FeatureHasher(n_features=10)
f = h.transform(vocabulary)
f.toarray()
# Out:
# array([[ 5128730.,   -18003., -3122563., -6115759.,   312894.,  5721570.,
#          3554191.,  1981390.,  1044407.,  2031793.]])

# %% [markdown]
# ## Apply sentiment analysis

# %% [markdown]
# STOCHASTIC_DESCENT applies Stochastic on the training data and returns the predicted labels
# Xtrain - Training Data
# Ytrain - Training Labels
# Xtest - Test Data

# %%
def stochastic_descent(Xtrain, Ytrain, Xtest):
    from sklearn.linear_model import SGDClassifier 
    clf = SGDClassifier(loss="hinge", penalty="l1", n_iter=20)
    print ("SGD Fitting")
    clf.fit(Xtrain, Ytrain)
    print ("SGD Predicting")
    Ytest = clf.predict(Xtest)
    return Ytest

# %% [markdown]
# ACCURACY finds the accuracy in percentage given the training and test labels
# Ytrain - One set of labels
# Ytest - Other set of labels

# %%
def accuracy(Ytrain, Ytest):
    assert (len(Ytrain)==len(Ytest))
    num =  sum([1 for i, word in enumerate(Ytrain) if Ytest[i]==word])
    n = len(Ytrain)  
    return (num*100)/n

# %%
def write_txt(data, name):
    data = ''.join(str(word) for word in data)
    file = open(name, 'w')
    file.write(data)
    file.close()
    pass

# %%
import time
start = time.time()

#imdb_data_preprocess(inpath=train_path, mix=True)
#imdb_data_preprocess(inpath=test_path, mix=True, name="imdb_te.csv")

[Xtrain_text, Ytrain] = retrieve_data()
[Xtest_text, Ytest] = retrieve_data(name="imdb_te.csv")

#ANALYSIS ON THE INSAMPLE DATA (TRAINING DATA)
## Unigram Model on the Train Data
uni_vectorizer = unigram_process(Xtrain_text)
Xtrain_uni = uni_vectorizer.transform(Xtrain_text)

## Bigram Model on the Train Data
bi_vectorizer = bigram_process(Xtrain_text)
Xtrain_bi = bi_vectorizer.transform(Xtrain_text)

## Unigram TF Model on the Train Data
uni_tfidf_transformer = tfidf_process(Xtrain_uni)
Xtrain_tf_uni = uni_tfidf_transformer.transform(Xtrain_uni)

## Bigram TF Model on the Train Data
bi_tfidf_transformer = tfidf_process(Xtrain_bi)
Xtrain_tf_bi = bi_tfidf_transformer.transform(Xtrain_bi)


#ANALYSIS ON THE TEST DATA
# Unigram Model on the Test Data
Xtest_uni = uni_vectorizer.transform(Xtest_text)
Ytest_uni = stochastic_descent(Xtrain_uni, Ytrain, Xtest_uni)
write_txt(Ytest_uni, name="unigram.output.txt")


# Bigram Model on the Test Data
Xtest_bi = bi_vectorizer.transform(Xtest_text)
Ytest_bi = stochastic_descent(Xtrain_bi, Ytrain, Xtest_bi)
write_txt(Ytest_bi, name="bigram.output.txt")


# Unigram TF Model on the Test Data
Xtest_tf_uni = uni_tfidf_transformer.transform(Xtest_uni)
Ytest_tf_uni = stochastic_descent(Xtrain_tf_uni, Ytrain, Xtest_tf_uni)
write_txt(Ytest_tf_uni, name="unigramtfidf.output.txt")


# Bigram TF Model on the Test Data
Xtest_tf_bi = bi_tfidf_transformer.transform(Xtest_bi)
Ytest_tf_bi = stochastic_descent(Xtrain_tf_bi, Ytrain, Xtest_tf_bi)
write_txt(Ytest_tf_bi, name="bigramtfidf.output.txt")

print ("Total time taken is ", time.time()-start, " seconds")
# Out:
# E:\Application\anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:73: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# SGD Fitting
# SGD Predicting
# E:\Application\anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:73: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# SGD Fitting
# SGD Predicting
# E:\Application\anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:73: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# SGD Fitting
# SGD Predicting
# E:\Application\anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:73: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# SGD Fitting
# SGD Predicting
# Total time taken is  89.54912805557251  seconds

# %%
print ("The accuracy of Unigram Model is ", accuracy(Ytest,Ytest_uni))
print ("The accuracy of Bigram Model is ", accuracy(Ytest,Ytest_bi))
print ("The accuracy of Unigram TF Model is ", accuracy(Ytest,Ytest_tf_uni))
print ("The accuracy of Bigram TF Model is ", accuracy(Ytest,Ytest_tf_bi))
# Out:
# The accuracy of Unigram Model is  85.0
# The accuracy of Bigram Model is  85.396
# The accuracy of Unigram TF Model is  87.268
# The accuracy of Bigram TF Model is  86.124

# %% [markdown]
# # Summary of the solution and key highlights

# %% [markdown]
# After removing stop word, tokenize, stem and transform punctuation,I tried four models to proceed the comment text,  they are Unigram Model, Bigram Model, Unigram TF Model and Bigram TF Model. Based on accuracy score, we can see that Unigram TF Model has the highest accuracy score, which is 87.268%, so this model is the best one for sentiment analysis.

# %% [markdown]
# # Key learnings

# %% [markdown]
# From this execise I learned how to preprocess text data and make them into feature matrix, also I learned that feature hashing is useful for magnanimous text data and save storage space. Since this data has labels so I just use machine learning method to train data with sentiment labels instead of sentiment analysis directly. If I have time in the future, I will definitely to try it and compare with this method.
