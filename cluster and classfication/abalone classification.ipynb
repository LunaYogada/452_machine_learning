# %%
from sklearn import datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
abalone = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data", names = ["Sex", "Length", "Diameter", "Height", "Whole Weight", "Shucked Weight", "Viscera Weight", "shell weight", "Rings"])

# %%
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
abalone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
# Sex               0 non-null float64
# Length            4177 non-null float64
# Diameter          4177 non-null float64
# Height            4177 non-null float64
# Whole Weight      4177 non-null float64
# Shucked Weight    4177 non-null float64
# Viscera Weight    4177 non-null float64
# shell weight      4177 non-null float64
# Rings             4177 non-null int64
# dtypes: float64(8), int64(1)
# memory usage: 293.8 KB

# %%
abalone.describe()
# Out:
#             Length     Diameter       Height  Whole Weight  Shucked Weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera Weight  shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
y = pd.get_dummies(data = abalone, columns = ['Sex']); y
# Out:
#       Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5      0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6      0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7      0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8      0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9      0.550     0.440   0.150        0.8945          0.3145          0.1510
# 10     0.525     0.380   0.140        0.6065          0.1940          0.1475
# ...

# %%
maps = {'F':1, 'M':0, 'I':2}
abalone["lab"]=abalone["Sex"].map(maps);abalone.head()
#abalone['Sex'] = abalone['Sex'].apply(lambda x: 1 if x =='F' 0 elif x=='M' 2 else x=='I' )
#abalone['Sex'].replace(0,'F',inplace = True)
#abalone['Sex'].replace(1,'M',inplace = True)
#abalone['Sex'].replace(2,'I',inplace = True)
#abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell weight  Rings  lab
# 0         0.150     15    0
# 1         0.070      7    0
# 2         0.210      9    1
# 3         0.155     10    0
# 4         0.055      7    2

# %%
abalone = abalone.drop(labels = 'Sex', axis =1)

# %%
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell weight  Rings  lab
# 0         0.150     15    0
# 1         0.070      7    0
# 2         0.210      9    1
# 3         0.155     10    0
# 4         0.055      7    2

# %%
sns.pairplot(abalone, hue = 'Sex')

# %%
corr = abalone.corr()
sns.heatmap(corr, xticklabels=corr.columns.values,
            yticklabels=corr.columns.values )

# %%
from sklearn.model_selection import train_test_split
x = abalone.copy().drop('lab',axis =1)
y = abalone['lab']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state = 1, stratify = y)

# %%
x_test.head()
# Out:
#       Length  Diameter  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 4109   0.480     0.365   0.130        0.5305          0.2405          0.1270
# 628    0.530     0.415   0.145        0.9440          0.3845          0.1850
# 1749   0.710     0.575   0.215        2.0090          0.9895          0.4475
# 4029   0.435     0.335   0.110        0.3340          0.1355          0.0775
# 3889   0.620     0.500   0.200        1.2210          0.4605          0.2630
#
#       shell weight  Rings
# 4109        0.1390      8
# 628         0.2650     21
# 1749        0.5020     11
# 4029        0.0965      7
# 3889        0.4300     12

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
from sklearn import svm
from sklearn.svm import SVC

# %%
svm = SVC(kernel='rbf', random_state=1, gamma=0.10, C=10.0)
svm.fit(x_train, y_train)
svm.score(x_train, y_train)
# Out:
# 0.56619911050290794

# %%
result = svm.predict(x_test);result
# Out:
# array([2, 0, 0, ..., 0, 0, 2], dtype=int64)

# %%
sns.distplot(result)
xlab
